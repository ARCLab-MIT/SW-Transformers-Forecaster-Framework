# %% [markdown]
# # Evaluation of SOLFSMY
#
# > With respect to the benchmark by Licata et al.

# %%
# Imports
import sys
sys.path.append('..')
from swdf.benchmark import *
from tsai.basics import *
from sklearn.metrics import mean_squared_error, mean_absolute_error
from swdf.utils import *
import wandb
from swdf.losses import *
wandb_api = wandb.Api()

# %%
# Constants
# ARTIFACT_DOWNLOAD_PATH = Path(os.environ["WANDB_DIR"])/"wandb/artifacts/solfsmy_eval_tmp"

# %%
# Config
config = yaml2dict('config/solfsmy.yaml')
config = config.eval

config_base = yaml2dict('config/base.yaml')

config, config_base
# Out:
# ({'dst_data_path': '../data/DST_IAGA2002.txt',
#   'learner_artifact': None,
#   'round_preds': True,
#   'solfsmy_data_path': '../data/SOLFSMY.TXT'},
#  {'arch_name': 'PatchTST',
#   'arch_config_file': 'config/patchtst.yaml',
#   'bs': 32,
#   'horizon': 6,
#   'init_weights': False,
#   'lookback': 36,
#   'lr_max': None,
#   'n_epoch': 50,
#   'partial_n': 0.1,
#   'seed': 42,
#   'test_start_datetime': '2012-10-01 12:00:00',
#   'test_end_datetime': '2018-12-31 12:00:00',
#   'valid_start_datetime': '2018-01-01 12:00:00',
#   'deltaHL': 4.0,
#   'is_optuna_study': False,
#   'wandb': {'enabled': False,
#    'log_learner': True,
#    'mode': 'offline',
#    'group': None,
#    'project': 'swdf'}})

# %%
learner1 = load_learner_all("tmp", model_fname = 'model_learner1', learner_fname="learner_learner1", 
                         verbose=True, 
                         device=default_device())

learner2 = load_learner_all("tmp", model_fname = 'model_learner2', learner_fname="learner_learner2", 
                         verbose=True, 
                         device=default_device())
# Out:
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth']'
# model_fname   = 'model_learner1.pth'
# learner_fname = 'learner_learner1.pkl'
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth']'
# model_fname   = 'model_learner2.pth'
# learner_fname = 'learner_learner2.pkl'

# %%
y_test_preds_learner1, y_test = learner1.get_preds(ds_idx = 2, with_targs=True)
y_test_preds_learner2, _ = learner2.get_preds(ds_idx = 2, with_targs=True) 

y_test_preds = (y_test_preds_learner1 + y_test_preds_learner2) / 2

y_test_preds = to_np(y_test_preds)
y_test = to_np(y_test)
print(f"y_test_preds.shape: {y_test_preds.shape}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# y_test_preds.shape: (2242, 4, 6)

# %%
horizon = y_test.shape[-1]
data_columns_fcst = ['F10', 'S10', 'M10', 'Y10']

# %% [markdown]
# The evaluation is done for each variable separately, for each solar activity
# level (low, moderate, elevated and high), as in the paper by Licata et al. (2020)
# Therefore, the test set has to be split into 4 different sets, one for each solar activity level. The thresholds for each solar activity level are the same as in the paper by Licata et al. (2020)
#
# The thresholds are:
# - F10: 75, 150, 190
# - S10: 65, 150, 215
# - M10: 72, 144, 167
# - Y10: 81, 148, 165

# %%
#|export

def get_idxs_per_solar_activity_level(data, thresholds):
    # function that splits the data of a variable into 4 different sets, 
    # one for each solar activity level. The data comes as a numpy array with 
    # shape (samples, steps), and the split is done along the samples axis. 
    # The decision is made based on the first column of each sample. The function 
    # returns a list of 4 numpy arrays, one for each solar activity level. 
    # But it does not return the values, it returns the indices of the
    # samples that belong to each solar activity level.
    idxs_per_solar_activity_level = []
    for i in range(len(thresholds) + 1):
        if i == 0:
            idxs = np.where(data[:, 0] <= thresholds[i])[0]
        elif i == len(thresholds):
            idxs = np.where(data[:, 0] > thresholds[i-1])[0]
        else:
            idxs = np.where((data[:, 0] > thresholds[i-1]) & (data[:, 0] <= thresholds[i]))[0]
        idxs_per_solar_activity_level.append(idxs)
    return idxs_per_solar_activity_level

# %%
# Call the function for each variable, using y_test
thresholds = {'F10': [75, 150, 190], 
              'S10': [65, 150, 215], 
              'M10': [72, 144, 167], 
              'Y10': [81, 148, 165]}

y_test_split_idxs = {}
for i, var in enumerate(data_columns_fcst):
    y_test_split_idxs[var] = get_idxs_per_solar_activity_level(y_test[:, i, :], 
                                                               thresholds[var])
# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(496,), (1463,), (283,), (0,)]
# M10: [(529,), (1465,), (223,), (25,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
df_SET = pd.read_pickle('preprocessed_data/dataframes/set_solfsmy.pkl')

_, y_test_SET = SlidingWindow(
            window_len=config_base.lookback,
            horizon=config_base.horizon, 
            stride=1, 
            get_x=['S10'], 
            get_y=['S10']
        )(df_SET)

y_test_split_idxs['S10'] = get_idxs_per_solar_activity_level(y_test_SET, thresholds['S10'])

# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(520,), (1421,), (267,), (33,)]
# M10: [(529,), (1465,), (223,), (25,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
# Now split y_test and y_test_preds with the idxs we got, using numpy.take
y_test_split = {}
y_test_preds_split = {}
for var in data_columns_fcst:
    y_test_split[var] = [y_test[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]
    y_test_preds_split[var] = [y_test_preds[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]

# Check the shape of each variable in y_test_split
for var in data_columns_fcst:
    print(f"y_test-{var}: {[y_test_split[var][i].shape for i in range(4)]}")
    print(f"y_test_preds-{var}: {[y_test_preds_split[var][i].shape for i in range(4)]}")
# Out:
# y_test-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test_preds-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test_preds-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test-M10: [(529, 6), (1465, 6), (223, 6), (25, 6)]
# y_test_preds-M10: [(529, 6), (1465, 6), (223, 6), (25, 6)]
# y_test-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]
# y_test_preds-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]

# %%
# Create a table (dataframe) with the mean forecast error for each variable (F10, S10, M10, Y10), 
# each solar activity level and each horizon (1..horizon)
data = []
sals = ['low', 'moderate', 'elevated', 'high']
for var_idx, var in enumerate(data_columns_fcst):
    for sal_idx,sal in enumerate(sals):
        for h in range(1, horizon+1):
            fe_sfu = forecast_error(y_test_split[var][sal_idx], 
                                y_test_preds_split[var][sal_idx], h)
            fe_percent = percent_forecast_error(y_test_split[var][sal_idx],
                                            y_test_preds_split[var][sal_idx], h)
            n_samples = y_test_split[var][sal_idx].shape[0]
            data.append([var, sal, h, np.mean(fe_sfu), np.std(fe_sfu), 
                        np.mean(fe_percent), np.std(fe_percent), n_samples])
df_results = pd.DataFrame(data, columns=['variable', 'condition', 'horizon', 
                                         'mean_sfu', 'std_sfu', 'mean_percent', 
                                         'std_percent', 'n_samples'])
df_results.head(10)
# Out:
#   variable condition  horizon  mean_sfu   std_sfu  mean_percent  std_percent  \
# 0      F10       low        1  0.791561  2.219116      1.123593     3.092625
# 1      F10       low        2  0.938428  2.583409      1.348677     3.595788
# 2      F10       low        3  0.749468  2.832440      1.106089     3.910083
# 3      F10       low        4  0.715458  3.131396      1.083112     4.264733
# 4      F10       low        5  0.585480  3.576443      0.942337     4.755487
# 5      F10       low        6  0.532711  3.986477      0.901129     5.192609
# 6      F10  moderate        1  0.450381  6.497828      0.502831     5.428945
# 7      F10  moderate        2  0.569295  7.594093      0.690587     6.367507
# 8      F10  moderate        3  0.329787  8.537539      0.565083     7.093308
# 9      F10  moderate        4  0.203760  9.416089      0.568437     7.782338
#
#    n_samples
# 0        591
# 1        591
# 2        591
# 3        591
# 4        591
# 5        591
# 6       1423
# 7       1423
# 8       1423
# 9       1423

# %%
# Divide the table into one dataframe for each variable, and print it in a way
# that has the same format as the table in the paper, that is:
# Columns: | Condition | Statistics | 1 Day | 2 Days | 3 Days | ... | {{horizon}} Days,
# where condition is the variable and the solar activity level, and statistics 
# is the mean (column mean_fe) and the standard deviation (std_fe) of the forecast error.
for i, var in enumerate(data_columns_fcst):
    df_var = df_results[df_results['variable'] == var]

    df_var = df_var.melt(id_vars=['condition', 'horizon'], 
                         value_vars=['mean_sfu', 'std_sfu'], 
                         var_name='Statistic')
    # Sort the values of the column condition so that the order is 
    # low, moderate, elevated, high
    df_var['condition'] = pd.Categorical(df_var['condition'], 
                                      categories=['low', 'moderate', 'elevated', 'high'], 
                                      ordered=True)
    df_var = df_var.pivot_table(index=['condition', 'Statistic'], 
                          columns='horizon', 
                          values='value')
    # pretty print, and separate with a blank line
    print(f'Distribution Statistics {var} Error Distribution \n{df_var.to_string()}\n')
# Out:
# Distribution Statistics F10 Error Distribution
# horizon                      1          2          3          4          5          6
# condition Statistic
# low       mean_sfu    0.791561   0.938428   0.749468   0.715458   0.585480   0.532711
#           std_sfu     2.219116   2.583409   2.832440   3.131396   3.576443   3.986477
# moderate  mean_sfu    0.450381   0.569295   0.329787   0.203760   0.297012   0.244356
#           std_sfu     6.497828   7.594093   8.537539   9.416089  10.252583  10.852441
# elevated  mean_sfu   -6.510151  -7.365026  -7.750527  -7.729567  -6.878181  -5.845489
#           std_sfu    10.367225  11.624657  13.447276  14.290874  15.173370  15.094501
# high      mean_sfu   -5.276302  -6.265727  -7.083208  -7.377884  -6.120494  -3.899212
#           std_sfu     6.683206   8.101572   8.492426   9.409459  10.976578  11.614598
#
# Distribution Statistics S10 Error Distribution
# horizon                     1         2          3          4          5          6
# condition Statistic
# low       mean_sfu  -0.059245 -0.073860  -0.171070  -0.249058  -0.306714  -0.403763
#           std_sfu    4.273148  6.322491   5.235913   5.790840   6.165984   7.848269
# moderate  mean_sfu  -0.277370 -0.255212  -0.450745  -0.579602  -0.391365  -0.343892
#           std_sfu    6.580608  7.657650   8.560536   9.431416  10.144048  10.697100
# elevated  mean_sfu  -0.269397 -0.070134  -0.565913  -0.498394  -0.177569  -0.175312
#           std_sfu    8.560597  9.638041  10.906992  11.833138  12.636051  12.340674
# high      mean_sfu  -4.475261 -4.299707  -3.213697  -1.320646  -0.924036   0.426977
#           std_sfu    6.676394  8.169419  10.875653  11.972663  12.530810  12.016236
#
# Distribution Statistics M10 Error Distribution
# horizon                     1          2          3          4          5          6
# condition Statistic
# low       mean_sfu   0.373369   0.498407   0.288883   0.248356   0.202847   0.199352
#           std_sfu    2.863012   3.368687   3.870206   4.269541   4.657211   4.986432
# moderate  mean_sfu   0.334787   0.376753   0.033005  -0.205385  -0.197475  -0.319264
#           std_sfu    6.369649   7.507798   8.467642   9.413597  10.202398  10.795148
# elevated  mean_sfu  -7.433798  -6.888823  -5.580474  -3.850679  -1.767082   0.124301
#           std_sfu    9.682113  11.492658  13.668193  14.428696  14.904848  14.164495
# high      mean_sfu  -2.302234  -2.966779  -2.905799  -1.452959  -0.460941   1.013579
#           std_sfu    7.353192   8.112887   9.347924   9.236442   9.937095  10.242769
#
# Distribution Statistics Y10 Error Distribution
# horizon                      1          2          3          4          5          6
# condition Statistic
# low       mean_sfu    0.608477   0.800836   0.657294   0.622061   0.605578   0.620032
#           std_sfu     2.643972   2.911500   2.992633   3.141783   3.364259   3.466874
# moderate  mean_sfu   -0.139255  -0.079187  -0.308607  -0.438640  -0.278386  -0.232659
#           std_sfu     6.594607   7.648643   8.547916   9.412986  10.162926  10.681859
# elevated  mean_sfu   -3.150171  -2.700614  -2.376429  -1.851920  -0.634131   0.298447
#           std_sfu     9.327755  10.717091  12.244484  12.464355  12.778612  12.345560
# high      mean_sfu  -14.681080 -11.115997  -8.029137  -3.011059   1.368961   2.523071
#           std_sfu     6.468994   5.335113   6.894571   8.470740  10.436807  12.480188

# %%
# Convert df_results into long format
df_results_lf = df_results.melt(id_vars=['variable', 'condition', 'horizon'],
                                value_vars=['mean_sfu', 'std_sfu', 'mean_percent', 'std_percent'],
                                var_name='statistic')

# Filter out the percent statistics
df_results_lf = df_results_lf[df_results_lf['statistic'].str.contains('percent') == False]

# Rename the Statistic 'mean_sfu' to just 'mean' and 'std_sfu' to 'std'
df_results_lf['statistic'] = df_results_lf['statistic'].str.replace('_sfu', '')

df_results_lf.head()
# Out:
#   variable condition  horizon statistic     value
# 0      F10       low        1      mean  0.791561
# 1      F10       low        2      mean  0.938428
# 2      F10       low        3      mean  0.749468
# 3      F10       low        4      mean  0.715458
# 4      F10       low        5      mean  0.585480

# %%
# Compare these results with the results in the paper. The results in the paper
# can be found in the data folder as a csv
df_results_paper = pd.read_csv('../data/paper_results.csv')

# Filter out the rows with Statistics = 'EBM'
df_results_paper = df_results_paper[df_results_paper['statistic'] != 'EBM']

# Rename the values of the column condition to the ones of the sals variable
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Low solar', 'low')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Moderate solar', 'moderate')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Elevated solar', 'elevated')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('High solar', 'high')

df_results_paper.head()
# Out:
#   variable condition statistic   1 Days   2 Days   3 Days   4 Days   5 Days  \
# 0      F10       low      mean  -0.2685  -0.7472  -0.6672  -0.3721  -0.0674
# 1      F10       low       std   3.6985   4.7031   5.5001   6.1683   6.7677
# 3      F10  moderate      mean  -0.8251  -0.8095  -0.9639  -1.1450  -1.1456
# 4      F10  moderate       std  12.0854  14.9853  17.8425  20.2973  21.9353
# 6      F10  elevated      mean   5.7270   7.2425   9.0385  10.3829  11.0017
#
#     6 Days
# 0   0.2428
# 1   7.2050
# 3  -1.1679
# 4  23.3389
# 6  10.9559

# %%
# Convert df_results_paper into long format
df_results_paper_lf = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'],
                                            value_vars=[f'{i} Days' for i in range(1, horizon+1)],
                                            var_name='horizon', value_name='value')

# Convert the value sof the horizon column to int
df_results_paper_lf['horizon'] = df_results_paper_lf['horizon'].str.replace(' Days', '').astype(int)
df_results_paper_lf.head()
# Out:
#   variable condition statistic  horizon    value
# 0      F10       low      mean        1  -0.2685
# 1      F10       low       std        1   3.6985
# 2      F10  moderate      mean        1  -0.8251
# 3      F10  moderate       std        1  12.0854
# 4      F10  elevated      mean        1   5.7270

# %%
# Join the two dataframes (df_results_ours and df_results_paper) on the columns 
# variable, condition and Statistic
df_results_joined = df_results_lf.merge(df_results_paper_lf, how='left', 
                                            on=['variable', 'condition', 'statistic', 'horizon'],
                                            suffixes=('_ours', '_paper'))
len(df_results_lf), len(df_results_paper_lf), len(df_results_joined)
# Out:
# (192, 192, 192)

# %% [markdown]
# ### Visualize predictions

# %%
df_long = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'], 
                      var_name='horizon', value_name='value')

df_long['horizon'] = df_long['horizon'].str.extract('(\d)').astype(int)
    
sfu_stats = df_long.groupby(['variable', 'condition','statistic', 'horizon']).agg(
        values=('value', 'mean')
    ).reset_index()

df_results_paper_formated = sfu_stats[['variable','condition','horizon']].iloc[np.where(sfu_stats['statistic'] == 'mean')]
df_results_paper_formated['std_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] != 'mean')].values
df_results_paper_formated['mean_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] == 'mean')].values
df_results_paper_formated['n_samples'] = np.nan
df_results_paper_formated['mean_sfu'] = np.nan
df_results_paper_formated['std_sfu'] = np.nan

df_results_paper_formated.reset_index()
# Out:
#     index variable condition  horizon  std_percent  mean_percent  n_samples  \
# 0       0      F10  elevated        1      18.3328        5.7270        NaN
# 1       1      F10  elevated        2      22.1021        7.2425        NaN
# 2       2      F10  elevated        3      25.2942        9.0385        NaN
# 3       3      F10  elevated        4      27.0774       10.3829        NaN
# 4       4      F10  elevated        5      27.5279       11.0017        NaN
# ..    ...      ...       ...      ...          ...           ...        ...
# 91    181      Y10  moderate        2      10.1811       -1.3317        NaN
# 92    182      Y10  moderate        3      11.8475       -1.7651        NaN
# 93    183      Y10  moderate        4      13.0170       -2.1734        NaN
# 94    184      Y10  moderate        5      13.8737       -2.5561        NaN
# 95    185      Y10  moderate        6      14.8937       -2.9688        NaN
#
#     mean_sfu  std_sfu
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 91       NaN      NaN
# 92       NaN      NaN
# 93       NaN      NaN
# 94       NaN      NaN
# 95       NaN      NaN
#
# [96 rows x 9 columns]

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'F10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'S10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'M10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'Y10')

# %%
pivoted_df = df_results_joined.pivot_table(index=['variable', 'condition', 'statistic'], 
                            columns='horizon', 
                            values=['value_ours','value_paper'], 
                            aggfunc='first').reset_index()

# To order the columns in the way that we want
condition_order = ['low', 'moderate', 'elevated', 'high']
pivoted_df['condition'] = pd.Categorical(pivoted_df['condition'], categories=condition_order, ordered=True)

# Format columns names
pivoted_df.columns = pd.MultiIndex.from_tuples(
    list(pivoted_df.columns[:3]) + 
    [(value, f'{i} Days Horizon') for value in ['Value Ours', 'Value Benchmark'] for i in range(1,7)]
)

pivoted_df = pivoted_df.sort_values([('variable',''),('condition','')])
pivoted_df.head(1)
# Out:
#   variable condition statistic     Value Ours                                \
#                                1 Days Horizon 2 Days Horizon 3 Days Horizon
# 4      F10       low      mean       0.791561       0.938428       0.749468
#
#                                                Value Benchmark                 \
#   4 Days Horizon 5 Days Horizon 6 Days Horizon  1 Days Horizon 2 Days Horizon
# 4       0.715458        0.58548       0.532711         -0.2685        -0.7472
#
#
#   3 Days Horizon 4 Days Horizon 5 Days Horizon 6 Days Horizon
# 4        -0.6672        -0.3721        -0.0674         0.2428

# %%
def highlight_max(row):
    # Empty color mask
    colors = [''] * len(row)
    columns = ['Value Ours', 'Value Benchmark']
    min_values = []
    
    for i in range(1,7):
        min_values.append(
            min(
                abs(row[('Value Ours', f'{i} Days Horizon')]), 
                abs(row[('Value Benchmark', f'{i} Days Horizon')])
            )
        )
    for i, value in enumerate(row[columns]):
        if np.abs(value) in min_values:
            colors[i+3] = 'background-color: grey'  # The 3 first columns are tags and no data
    return colors

# Compare and highlight # Get max of each element in both dataframes
styled_result = pivoted_df.style.apply(highlight_max, axis=1)

styled_result
# Out:
# <style type="text/css">
# #T_00590_row0_col9, #T_00590_row0_col10, #T_00590_row0_col11, #T_00590_row0_col12, #T_00590_row0_col13, #T_00590_row0_col14, #T_00590_row1_col3, #T_00590_row1_col4, #T_00590_row1_col5, #T_00590_row1_col6, #T_00590_row1_col7, #T_00590_row1_col8, #T_00590_row2_col3, #T_00590_row2_col4, #T_00590_row2_col5, #T_00590_row2_col6, #T_00590_row2_col7, #T_00590_row2_col8, #T_00590_row3_col3, #T_00590_row3_col4, #T_00590_row3_col5, #T_00590_row3_col6, #T_00590_row3_col7, #T_00590_row3_col8, #T_00590_row4_col5, #T_00590_row4_col6, #T_00590_row4_col7, #T_00590_row4_col8, #T_00590_row4_col9, #T_00590_row4_col10, #T_00590_row5_col3, #T_00590_row5_col4, #T_00590_row5_col5, #T_00590_row5_col6, #T_00590_row5_col7, #T_00590_row5_col8, #T_00590_row6_col3, #T_00590_row6_col4, #T_00590_row6_col5, #T_00590_row6_col6, #T_00590_row6_col7, #T_00590_row6_col8, #T_00590_row7_col3, #T_00590_row7_col4, #T_00590_row7_col5, #T_00590_row7_col6, #T_00590_row7_col7, #T_00590_row7_col8, #T_00590_row8_col3, #T_00590_row8_col4, #T_00590_row8_col5, #T_00590_row8_col6, #T_00590_row8_col7, #T_00590_row8_col8, #T_00590_row9_col3, #T_00590_row9_col4, #T_00590_row9_col5, #T_00590_row9_col6, #T_00590_row9_col7, #T_00590_row9_col8, #T_00590_row10_col3, #T_00590_row10_col4, #T_00590_row10_col5, #T_00590_row10_col6, #T_00590_row10_col7, #T_00590_row10_col8, #T_00590_row11_col3, #T_00590_row11_col4, #T_00590_row11_col5, #T_00590_row11_col6, #T_00590_row11_col7, #T_00590_row11_col8, #T_00590_row12_col5, #T_00590_row12_col6, #T_00590_row12_col7, #T_00590_row12_col8, #T_00590_row12_col9, #T_00590_row12_col10, #T_00590_row13_col3, #T_00590_row13_col4, #T_00590_row13_col5, #T_00590_row13_col6, #T_00590_row13_col7, #T_00590_row13_col8, #T_00590_row14_col3, #T_00590_row14_col4, #T_00590_row14_col5, #T_00590_row14_col6, #T_00590_row14_col7, #T_00590_row14_col8, #T_00590_row15_col3, #T_00590_row15_col4, #T_00590_row15_col5, #T_00590_row15_col6, #T_00590_row15_col7, #T_00590_row15_col8, #T_00590_row16_col3, #T_00590_row16_col10, #T_00590_row16_col11, #T_00590_row16_col12, #T_00590_row16_col13, #T_00590_row16_col14, #T_00590_row17_col3, #T_00590_row17_col5, #T_00590_row17_col6, #T_00590_row17_col10, #T_00590_row17_col13, #T_00590_row17_col14, #T_00590_row18_col9, #T_00590_row18_col10, #T_00590_row18_col11, #T_00590_row18_col12, #T_00590_row18_col13, #T_00590_row18_col14, #T_00590_row19_col3, #T_00590_row19_col4, #T_00590_row19_col5, #T_00590_row19_col6, #T_00590_row19_col7, #T_00590_row19_col8, #T_00590_row20_col3, #T_00590_row20_col4, #T_00590_row20_col5, #T_00590_row20_col6, #T_00590_row20_col7, #T_00590_row20_col8, #T_00590_row21_col3, #T_00590_row21_col4, #T_00590_row21_col5, #T_00590_row21_col6, #T_00590_row21_col7, #T_00590_row21_col8, #T_00590_row22_col3, #T_00590_row22_col4, #T_00590_row22_col5, #T_00590_row22_col6, #T_00590_row22_col7, #T_00590_row22_col8, #T_00590_row23_col3, #T_00590_row23_col4, #T_00590_row23_col5, #T_00590_row23_col6, #T_00590_row23_col7, #T_00590_row23_col8, #T_00590_row24_col9, #T_00590_row24_col10, #T_00590_row24_col11, #T_00590_row24_col12, #T_00590_row24_col13, #T_00590_row24_col14, #T_00590_row25_col3, #T_00590_row25_col4, #T_00590_row25_col5, #T_00590_row25_col6, #T_00590_row25_col7, #T_00590_row25_col8, #T_00590_row26_col3, #T_00590_row26_col4, #T_00590_row26_col5, #T_00590_row26_col6, #T_00590_row26_col7, #T_00590_row26_col8, #T_00590_row27_col3, #T_00590_row27_col4, #T_00590_row27_col5, #T_00590_row27_col6, #T_00590_row27_col7, #T_00590_row27_col8, #T_00590_row28_col6, #T_00590_row28_col7, #T_00590_row28_col8, #T_00590_row28_col9, #T_00590_row28_col10, #T_00590_row28_col11, #T_00590_row29_col9, #T_00590_row29_col10, #T_00590_row29_col11, #T_00590_row29_col12, #T_00590_row29_col13, #T_00590_row29_col14, #T_00590_row30_col6, #T_00590_row30_col7, #T_00590_row30_col8, #T_00590_row30_col9, #T_00590_row30_col10, #T_00590_row30_col11, #T_00590_row31_col3, #T_00590_row31_col4, #T_00590_row31_col5, #T_00590_row31_col6, #T_00590_row31_col7, #T_00590_row31_ ...
#   background-color: grey;
# }
# </style>
# <table id="T_00590">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00590_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_00590_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_00590_level0_col2" class="col_heading level0 col2" >statistic</th>
#       <th id="T_00590_level0_col3" class="col_heading level0 col3" colspan="6">Value Ours</th>
#       <th id="T_00590_level0_col9" class="col_heading level0 col9" colspan="6">Value Benchmark</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_00590_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_00590_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_00590_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_00590_level1_col3" class="col_heading level1 col3" >1 Days Horizon</th>
#       <th id="T_00590_level1_col4" class="col_heading level1 col4" >2 Days Horizon</th>
#       <th id="T_00590_level1_col5" class="col_heading level1 col5" >3 Days Horizon</th>
#       <th id="T_00590_level1_col6" class="col_heading level1 col6" >4 Days Horizon</th>
#       <th id="T_00590_level1_col7" class="col_heading level1 col7" >5 Days Horizon</th>
#       <th id="T_00590_level1_col8" class="col_heading level1 col8" >6 Days Horizon</th>
#       <th id="T_00590_level1_col9" class="col_heading level1 col9" >1 Days Horizon</th>
#       <th id="T_00590_level1_col10" class="col_heading level1 col10" >2 Days Horizon</th>
#       <th id="T_00590_level1_col11" class="col_heading level1 col11" >3 Days Horizon</th>
#       <th id="T_00590_level1_col12" class="col_heading level1 col12" >4 Days Horizon</th>
#       <th id="T_00590_level1_col13" class="col_heading level1 col13" >5 Days Horizon</th>
#       <th id="T_00590_level1_col14" class="col_heading level1 col14" >6 Days Horizon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00590_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_00590_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_00590_row0_col1" class="data row0 col1" >low</td>
#       <td id="T_00590_row0_col2" class="data row0 col2" >mean</td>
#       <td id="T_00590_row0_col3" class="data row0 col3" >0.791561</td>
#       <td id="T_00590_row0_col4" class="data row0 col4" >0.938428</td>
#       <td id="T_00590_row0_col5" class="data row0 col5" >0.749468</td>
#       <td id="T_00590_row0_col6" class="data row0 col6" >0.715458</td>
#       <td id="T_00590_row0_col7" class="data row0 col7" >0.585480</td>
#       <td id="T_00590_row0_col8" class="data row0 col8" >0.532711</td>
#       <td id="T_00590_row0_col9" class="data row0 col9" >-0.268500</td>
#       <td id="T_00590_row0_col10" class="data row0 col10" >-0.747200</td>
#       <td id="T_00590_row0_col11" class="data row0 col11" >-0.667200</td>
#       <td id="T_00590_row0_col12" class="data row0 col12" >-0.372100</td>
#       <td id="T_00590_row0_col13" class="data row0 col13" >-0.067400</td>
#       <td id="T_00590_row0_col14" class="data row0 col14" >0.242800</td>
#     </tr>
#     <tr>
#       <th id="T_00590_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_00590_row1_col0" class="data row1 col0" >F10</td>
#       <td id="T_00590_row1_col1" class="data row1 col1" >low</td>
#       <td id="T_00590_row1_col2" class="data row1 col2" >std</td>
#       <td id="T_00590_row1_col3" class="data row1 col3" >2.219116</td>
#       <td id="T_00590_row1_col4" class="data row1 col4" >2.583409</td>
#       <td id="T_00590_row1_col5" class="data row1 col5" >2.832440</td>
#       <td id="T_00590_row1_col6" class="data row1 col6" >3.131396</td>
#       <td id="T_00590_row1_col7" class="data row1 col7" >3.576443</td>
#       <td id="T_00590_row1_col8" class="data row1 col8" >3.986477</td>
#       <td id="T_00590_row1_col9" class="data row1 col9" >3.698500</td>
#       <td id="T_00590_row1_col10" class="data row1 col10" >4.703100</td>
#       <td

# %%
improvement_df = pivoted_df.copy()
for i in range(1, 7):
    improvement_df[f'Improvement {i}'] = (improvement_df[('Value Ours', f'{i} Days Horizon')] - improvement_df[('Value Benchmark', f'{i} Days Horizon')]) / improvement_df[('Value Benchmark', f'{i} Days Horizon')] * 100

overall_mean_improvement = improvement_df.groupby('statistic')[[(f'Improvement {i}','')  for i in range(1, 7)]].mean().mean(axis=1)
variable_mean_improvement = improvement_df.groupby(['variable', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)
condition_mean_improvement = improvement_df.groupby(['condition', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)
var_cond_mean_improvement = improvement_df.groupby(['variable', 'condition', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)

variable_mean_improvement.keys()
# Out:
# MultiIndex([('F10', 'mean'),
#             ('F10',  'std'),
#             ('M10', 'mean'),
#             ('M10',  'std'),
#             ('S10', 'mean'),
#             ('S10',  'std'),
#             ('Y10', 'mean'),
#             ('Y10',  'std')],
#            names=['variable', 'statistic'])

# %%
aligned_series1 = pd.Series(overall_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [('', 'overall', 'mean'), ('', 'overall', 'std')], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )
aligned_series2 = pd.Series(variable_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [(key[0],) + ('',) + (key[1],)  for key in variable_mean_improvement.keys()], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )
aligned_series3 = pd.Series(condition_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [('',) + key for key in condition_mean_improvement.keys()], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )

# Concatenate the aligned series
performance_comparison_df = pd.DataFrame(pd.concat([aligned_series1, aligned_series2, aligned_series3, var_cond_mean_improvement], axis=0), columns=['Improvement'])
performance_comparison_df.dropna(inplace=True)

# %%
def color_gradient(val, df=performance_comparison_df):
    max_val = df['Improvement'].max()
    min_val = df['Improvement'].min()
    range_val = np.abs(max_val - min_val)
    normalized_val = np.abs(val - min_val) / range_val
    
    red = int(255 * normalized_val)
    green = int(255 * (1 - normalized_val))
    
    return f'background-color: rgb({red},{green},0); color: black'

styled_df = performance_comparison_df.style.applymap(color_gradient, subset=['Improvement'])
styled_df
# Out:
# <style type="text/css">
# #T_c2a08_row0_col0 {
#   background-color: rgb(89,165,0);
#   color: black;
# }
# #T_c2a08_row1_col0, #T_c2a08_row13_col0, #T_c2a08_row27_col0, #T_c2a08_row37_col0 {
#   background-color: rgb(137,117,0);
#   color: black;
# }
# #T_c2a08_row2_col0 {
#   background-color: rgb(63,191,0);
#   color: black;
# }
# #T_c2a08_row3_col0, #T_c2a08_row17_col0, #T_c2a08_row21_col0, #T_c2a08_row39_col0 {
#   background-color: rgb(130,124,0);
#   color: black;
# }
# #T_c2a08_row4_col0 {
#   background-color: rgb(91,163,0);
#   color: black;
# }
# #T_c2a08_row5_col0, #T_c2a08_row11_col0 {
#   background-color: rgb(139,115,0);
#   color: black;
# }
# #T_c2a08_row6_col0 {
#   background-color: rgb(125,129,0);
#   color: black;
# }
# #T_c2a08_row7_col0 {
#   background-color: rgb(136,118,0);
#   color: black;
# }
# #T_c2a08_row8_col0 {
#   background-color: rgb(77,177,0);
#   color: black;
# }
# #T_c2a08_row9_col0 {
#   background-color: rgb(145,109,0);
#   color: black;
# }
# #T_c2a08_row10_col0 {
#   background-color: rgb(106,148,0);
#   color: black;
# }
# #T_c2a08_row12_col0 {
#   background-color: rgb(84,170,0);
#   color: black;
# }
# #T_c2a08_row14_col0 {
#   background-color: rgb(80,174,0);
#   color: black;
# }
# #T_c2a08_row15_col0, #T_c2a08_row45_col0 {
#   background-color: rgb(142,112,0);
#   color: black;
# }
# #T_c2a08_row16_col0 {
#   background-color: rgb(86,168,0);
#   color: black;
# }
# #T_c2a08_row18_col0 {
#   background-color: rgb(0,255,0);
#   color: black;
# }
# #T_c2a08_row19_col0, #T_c2a08_row23_col0, #T_c2a08_row43_col0 {
#   background-color: rgb(133,121,0);
#   color: black;
# }
# #T_c2a08_row20_col0 {
#   background-color: rgb(90,164,0);
#   color: black;
# }
# #T_c2a08_row22_col0 {
#   background-color: rgb(69,185,0);
#   color: black;
# }
# #T_c2a08_row24_col0 {
#   background-color: rgb(95,159,0);
#   color: black;
# }
# #T_c2a08_row25_col0 {
#   background-color: rgb(122,132,0);
#   color: black;
# }
# #T_c2a08_row26_col0, #T_c2a08_row32_col0 {
#   background-color: rgb(96,158,0);
#   color: black;
# }
# #T_c2a08_row28_col0, #T_c2a08_row40_col0 {
#   background-color: rgb(102,152,0);
#   color: black;
# }
# #T_c2a08_row29_col0 {
#   background-color: rgb(138,116,0);
#   color: black;
# }
# #T_c2a08_row30_col0 {
#   background-color: rgb(71,183,0);
#   color: black;
# }
# #T_c2a08_row31_col0 {
#   background-color: rgb(146,108,0);
#   color: black;
# }
# #T_c2a08_row33_col0 {
#   background-color: rgb(134,120,0);
#   color: black;
# }
# #T_c2a08_row34_col0 {
#   background-color: rgb(255,0,0);
#   color: black;
# }
# #T_c2a08_row35_col0 {
#   background-color: rgb(154,100,0);
#   color: black;
# }
# #T_c2a08_row36_col0 {
#   background-color: rgb(29,225,0);
#   color: black;
# }
# #T_c2a08_row38_col0, #T_c2a08_row44_col0 {
#   background-color: rgb(114,140,0);
#   color: black;
# }
# #T_c2a08_row41_col0 {
#   background-color: rgb(120,134,0);
#   color: black;
# }
# #T_c2a08_row42_col0 {
#   background-color: rgb(75,179,0);
#   color: black;
# }
# #T_c2a08_row46_col0 {
#   background-color: rgb(68,186,0);
#   color: black;
# }
# #T_c2a08_row47_col0 {
#   background-color: rgb(160,94,0);
#   color: black;
# }
# #T_c2a08_row48_col0 {
#   background-color: rgb(52,202,0);
#   color: black;
# }
# #T_c2a08_row49_col0 {
#   background-color: rgb(144,110,0);
#   color: black;
# }
# </style>
# <table id="T_c2a08">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2a08_level0_col0" class="col_heading level0 col0" >Improvement</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="index_name level1" >condition</th>
#       <th class="index_name level2" >statistic</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c2a08_level0_row0" class="row_heading level0 row0" rowspan="2"></th>
#       <th id="T_c2a08_level1_row0" class="row_heading level1 row0" rowspan="2">overall</th>
#       <th id="T_c2a08_level2_row0" class="row_heading level2 row0" >mean</th>
#       <td id="T_c2a08_row0_col0" class="data row0 col0" >-138.657423</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row1" class="row_heading level2 row1" >std</th>
#       <td id="T_c2a08_row1_col0" class="data row1 col0" >-36.526179</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level0_row2" class="row_heading level0 row2" rowspan="2">F10</th>
#       <th id="T_c2a08_level1_row2" class="row_heading level1 row2" rowspan="2"></th>
#       <th id="T_c2a08_level2_row2" class="row_heading level2 row2" >mean</th>
#       <td id="T_c2a08_row2_col0" class="data row2 col0" >-193.819122</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row3" class="row_heading level2 row3" >std</th>
#       <td id="T_c2a08_row3_col0" class="data row3 col0" >-52.696217</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level0_row4" class="row_heading level0 row4" rowspan="2">M10</th>
#       <th id="T_c2a08_level1_row4" class="row_heading level1 row4" rowspan="2"></th>
#       <th id="T_c2a08_level2_row4" class="row_heading level2 row4" >mean</th>
#       <td id="T_c2a08_row4_col0" class="data row4 col0" >-133.778506</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row5" class="row_heading level2 row5" >std</th>
#       <td id="T_c2a08_row5_col0" class="data row5 col0" >-33.035119</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level0_row6" class="row_heading level0 row6" rowspan="2">S10</th>
#       <th id="T_c2a08_level1_row6" class="row_heading level1 row6" rowspan="2"></th>
#       <th id="T_c2a08_level2_row6" class="row_heading level2 row6" >mean</th>
#       <td id="T_c2a08_row6_col0" class="data row6 col0" >-62.761042</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row7" class="row_heading level2 row7" >std</th>
#       <td id="T_c2a08_row7_col0" class="data row7 col0" >-40.124896</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level0_row8" class="row_heading level0 row8" rowspan="2">Y10</th>
#       <th id="T_c2a08_level1_row8" class="row_heading level1 row8" rowspan="2"></th>
#       <th id="T_c2a08_level2_row8" class="row_heading level2 row8" >mean</th>
#       <td id="T_c2a08_row8_col0" class="data row8 col0" >-164.271020</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row9" class="row_heading level2 row9" >std</th>
#       <td id="T_c2a08_row9_col0" class="data row9 col0" >-20.248484</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level0_row10" class="row_heading level0 row10" rowspan="8"></th>
#       <th id="T_c2a08_level1_row10" class="row_heading level1 row10" rowspan="2">low</th>
#       <th id="T_c2a08_level2_row10" class="row_heading level2 row10" >mean</th>
#       <td id="T_c2a08_row10_col0" class="data row10 col0" >-102.300246</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row11" class="row_heading level2 row11" >std</th>
#       <td id="T_c2a08_row11_col0" class="data row11 col0" >-31.962785</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level1_row12" class="row_heading level1 row12" rowspan="2">moderate</th>
#       <th id="T_c2a08_level2_row12" class="row_heading level2 row12" >mean</th>
#       <td id="T_c2a08_row12_col0" class="data row12 col0" >-150.389469</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row13" class="row_heading level2 row13" >std</th>
#       <td id="T_c2a08_row13_col0" class="data row13 col0" >-37.355646</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level1_row14" class="row_heading level1 row14" rowspan="2">elevated</th>
#       <th id="T_c2a08_level2_row14" class="row_heading level2 row14" >mean</th>
#       <td id="T_c2a08_row14_col0" class="data row14 col0" >-157.244993</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row15" class="row_heading level2 row15" >std</th>
#       <td id="T_c2a08_row15_col0" class="data row15 col0" >-25.525003</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level1_row16" class="row_heading level1 row16" rowspan="2">high</th>
#       <th id="T_c2a08_level2_row16" class="row_heading level2 row16" >mean</th>
#       <td id="T_c2a08_row16_col0" class="data row16 col0" >-144.694982</td>
#     </tr>
#     <tr>
#       <th id="T_c2a08_level2_row17" class="row_heading level2 row17" >std</th>
#       <td id="T_c2a08_row17_col0" class="data row17 col0" >-51.261281</td>
#     </tr>
#     <

# %%
create_latex_comparison_tables(df_results_joined, data_columns_fcst, horizon)
# Out:
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable F10}
# \label{tab:comparison_F10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & 0.79156053 ± \textbf{2.2191162} & \textbf{-0.2685} ± 3.6985 \\
# low & 2 & 0.93842846 ± \textbf{2.5834088} & \textbf{-0.7472} ± 4.7031 \\
# low & 3 & 0.74946845 ± \textbf{2.8324404} & \textbf{-0.6672} ± 5.5001 \\
# low & 4 & 0.7154578 ± \textbf{3.1313958} & \textbf{-0.3721} ± 6.1683 \\
# low & 5 & 0.58548033 ± \textbf{3.5764427} & \textbf{-0.0674} ± 6.7677 \\
# low & 6 & 0.532711 ± \textbf{3.986477} & \textbf{0.2428} ± 7.205 \\
# moderate & 1 & \textbf{0.45038113} ± \textbf{6.497828} & -0.8251 ± 12.0854 \\
# moderate & 2 & \textbf{0.5692947} ± \textbf{7.5940933} & -0.8095 ± 14.9853 \\
# moderate & 3 & \textbf{0.3297867} ± \textbf{8.5375395} & -0.9639 ± 17.8425 \\
# moderate & 4 & \textbf{0.20376022} ± \textbf{9.416089} & -1.145 ± 20.2973 \\
# moderate & 5 & \textbf{0.29701212} ± \textbf{10.252583} & -1.1456 ± 21.9353 \\
# moderate & 6 & \textbf{0.24435624} ± \textbf{10.852441} & -1.1679 ± 23.3389 \\
# elevated & 1 & -6.5101514 ± \textbf{10.367225} & \textbf{5.727} ± 18.3328 \\
# elevated & 2 & -7.365026 ± \textbf{11.624657} & \textbf{7.2425} ± 22.1021 \\
# elevated & 3 & \textbf{-7.750527} ± \textbf{13.447276} & 9.0385 ± 25.2942 \\
# elevated & 4 & \textbf{-7.729567} ± \textbf{14.2908745} & 10.3829 ± 27.0774 \\
# elevated & 5 & \textbf{-6.878181} ± \textbf{15.17337} & 11.0017 ± 27.5279 \\
# elevated & 6 & \textbf{-5.8454885} ± \textbf{15.0945015} & 10.9559 ± 26.9074 \\
# high & 1 & \textbf{-5.2763023} ± \textbf{6.683206} & 15.7448 ± 20.2227 \\
# high & 2 & \textbf{-6.2657266} ± \textbf{8.101572} & 19.5749 ± 24.7236 \\
# high & 3 & \textbf{-7.0832076} ± \textbf{8.492426} & 24.2444 ± 27.6092 \\
# high & 4 & \textbf{-7.3778844} ± \textbf{9.409459} & 26.6674 ± 30.8869 \\
# high & 5 & \textbf{-6.120494} ± \textbf{10.976578} & 26.023 ± 33.9069 \\
# high & 6 & \textbf{-3.8992116} ± \textbf{11.614598} & 23.9778 ± 35.9795 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable S10}
# \label{tab:comparison_S10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.059244685} ± \textbf{4.273148} & 0.2206 ± 5.8378 \\
# low & 2 & -0.07386027 ± 6.3224907 & \textbf{-0.0343} ± \textbf{5.7474} \\
# low & 3 & -0.17107002 ± \textbf{5.2359133} & \textbf{-0.1044} ± 5.8682 \\
# low & 4 & -0.24905829 ± \textbf{5.7908397} & \textbf{-0.0985} ± 6.0709 \\
# low & 5 & -0.3067142 ± 6.1659837 & \textbf{-0.066} ± \textbf{6.1153} \\
# low & 6 & -0.40376306 ± 7.848269 & \textbf{-0.0501} ± \textbf{6.0475} \\
# moderate & 1 & -0.27737018 ± \textbf{6.580608} & \textbf{0.1111} ± 10.0715 \\
# moderate & 2 & -0.2552123 ± \textbf{7.6576495} & \textbf{0.219} ± 11.7059 \\
# moderate & 3 & -0.4507446 ± \textbf{8.560536} & \textbf{0.2974} ± 13.5434 \\
# moderate & 4 & -0.57960236 ± \textbf{9.431416} & \textbf{0.3426} ± 14.9844 \\
# moderate & 5 & -0.39136508 ± \textbf{10.144048} & \textbf{0.2977} ± 16.1132 \\
# moderate & 6 & -0.34389234 ± \textbf{10.6971} & \textbf{0.1862} ± 17.1467 \\
# elevated & 1 & \textbf{-0.26939672} ± \textbf{8.560597} & -1.1311 ± 16.5592 \\
# elevated & 2 & \textbf{-0.07013425} ± \textbf{9.6380415} & -1.7989 ± 19.205 \\
# elevated & 3 & \textbf{-0.56591266} ± \textbf{10.906992} & -2.2361 ± 21.9271 \\
# elevated & 4 & \textbf{-0.4983941} ± \textbf{11.8331375} & -2.691 ± 24.1118 \\
# elevated & 5 & \textbf{-0.17756942} ± \textbf{12.636051} & -2.8148 ± 25.8017 \\
# elevated & 6 & \textbf{-0.17531177} ± \textbf{12.340674} & -2.7593 ± 27.2658 \\
# high & 1 & \textbf{-4.475261} ± \textbf{6.6763935} & 16.204 ± 35.3267 \\
# high & 2 & \textbf{-4.299707} ± \textbf{8.169419} & 23.1628 ± 39.6577 \\
# high & 3 & \textbf{-3.2136972} ± \textbf{10.875653} & 28.3943 ± 39.6471 \\
# high & 4 & \textbf{-1.3206463} ± \textbf{11.972663} & 31.4085 ± 38.7875 \\
# high & 5 & \textbf{-0.9240362} ± \textbf{12.53081} & 31.6158 ± 38.5307 \\
# high & 6 & \textbf{0.42697746} ± \textbf{12.016236} & 30.1409 ± 38.6613 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable M10}
# \label{tab:comparison_M10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{0.37336937} ± \textbf{2.8630118} & -0.9582 ± 5.1317 \\
# low & 2 & \textbf{0.49840748} ± \textbf{3.368687} & -1.1063 ± 5.6375 \\
# low & 3 & \textbf{0.28888273} ± \textbf{3.8702056} & -1.2667 ± 6.225 \\
# low & 4 & \textbf{0.24835634} ± \textbf{4.269541} & -1.4203 ± 6.4693 \\
# low & 5 & \textbf{0.20284663} ± \textbf{4.6572113} & -1.5303 ± 6.8538 \\
# low & 6 & \textbf{0.19935162} ± \textbf{4.986432} & -1.6171 ± 7.2024 \\
# moderate & 1 & \textbf{0.33478704} ± \textbf{6.369649} & -0.5138 ± 8.9027 \\
# moderate & 2 & \textbf{0.37675276} ± \textbf{7.5077977} & -0.7424 ± 11.2745 \\
# moderate & 3 & \textbf{0.033004582} ± \textbf{8.467642} & -0.9976 ± 13.4329 \\
# moderate & 4 & \textbf{-0.20538497} ± \textbf{9.413597} & -1.1619 ± 15.1962 \\
# moderate & 5 & \textbf{-0.19747469} ± \textbf{10.202398} & -1.237 ± 16.4221 \\
# moderate & 6 & \textbf{-0.319264} ± \textbf{10.795148} & -1.3348 ± 17.4041 \\
# elevated & 1 & -7.4337983 ± \textbf{9.682113} & \textbf{3.7282} ± 10.4528 \\
# elevated & 2 & -6.888823 ± \textbf{11.492658} & \textbf{5.6301} ± 13.4784 \\
# elevated & 3 & \textbf{-5.5804744} ± \textbf{13.668193} & 7.3375 ± 16.1156 \\
# elevated & 4 & \textbf{-3.850679} ± \textbf{14.428696} & 8.5258 ± 17.9805 \\
# elevated & 5 & \textbf{-1.7670825} ± \textbf{14.904848} & 9.0192 ± 18.9175 \\
# elevated & 6 & \textbf{0.12430087} ± \textbf{14.164495} & 8.9334 ± 19.077 \\
# high & 1 & \textbf{-2.302234} ± \textbf{7.3531923} & 4.6517 ± 9.2079 \\
# high & 2 & \textbf{-2.9667792} ± \textbf{8.112887} & 6.3966 ± 12.7892 \\
# high & 3 & \textbf{-2.905799} ± \textbf{9.347924} & 8.8328 ± 16.4932 \\
# high & 4 & \textbf{-1.452959} ± \textbf{9.236442} & 10.95 ± 19.2241 \\
# high & 5 & \textbf{-0.46094054} ± \textbf{9.937095} & 12.3435 ± 20.913 \\
# high & 6 & \textbf{1.0135788} ± \textbf{10.242769} & 12.9784 ± 21.582 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable Y10}
# \label{tab:comparison_Y10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & 0.6084771 ± \textbf{2.6439724} & \textbf{-0.427} ± 4.5093 \\
# low & 2 & 0.8008357 ± \textbf{2.9115} & \textbf{-0.2282} ± 4.9373 \\
# low & 3 & 0.65729403 ± \textbf{2.9926333} & \textbf{-0.0684} ± 5.4416 \\
# low & 4 & 0.6220612 ± \textbf{3.141783} & \textbf{0.0902} ± 5.9977 \\
# low & 5 & 0.6055781 ± \textbf{3.364259} & \textbf{0.2697} ± 6.4255 \\
# low & 6 & 0.62003225 ± \textbf{3.4668741} & \textbf{0.465} ± 6.816 \\
# moderate & 1 & \textbf{-0.13925546} ± \textbf{6.594607} & -0.8277 ± 8.5137 \\
# moderate & 2 & \textbf{-0.07918679} ± \textbf{7.6486425} & -1.3317 ± 10.1811 \\
# moderate & 3 & \textbf{-0.30860728} ± \textbf{8.547916} & -1.7651 ± 11.8475 \\
# moderate & 4 & \textbf{-0.43864045} ± \textbf{9.412986} & -2.1734 ± 13.017 \\
# moderate & 5 & \textbf{-0.27838615} ± \textbf{10.162926} & -2.5561 ± 13.8737 \\
# moderate & 6 & \textbf{-0.23265907} ± \textbf{10.681859} & -2.9688 ± 14.8937 \\
# elevated & 1 & -3.1501708 ± 9.327755 & \textbf{2.1089} ± \textbf{7.7173} \\
# elevated & 2 & -2.7006145 ± 10.717091 & \textbf{1.7243} ± \textbf{9.3066} \\
# elevated & 3 & -2.3764293 ± 12.244484 & \textbf{2.0679} ± \textbf{10.6086} \\
# elevated & 4 & \textbf{-1.8519204} ± 12.464355 & 2.5656 ± \textbf{11.4955} \\
# elevated & 5 & \textbf{-0.6341312} ± 12.778612 & 2.7714 ± \textbf{11.8996} \\
# elevated & 6 & \textbf{0.2984465} ± 12.34556 & 2.8423 ± \textbf{11.9965} \\
# high & 1 & -14.68108 ± \textbf{6.468994} & \textbf{5.2729} ± 8.5806 \\
# high & 2 & -11.115997 ± \textbf{5.335113} & \textbf{4.2075} ± 10.8097 \\
# high & 3 & -8.029137 ± \textbf{6.8945713} & \textbf{4.5855} ± 11.5436 \\
# high & 4 & \textbf{-3.0110588} ± \textbf{8.47074} & 5.2131 ± 11.3048 \\
# high & 5 & \textbf{1.3689613} ± \textbf{10.436807} & 5.6561 ± 11.019 \\
# high & 6 & \textbf{2.5230713} ± 12.480188 & 6.014 ± \textbf{10.4416} \\
# \bottomrule
# \end{tabular}
# \end{table}
