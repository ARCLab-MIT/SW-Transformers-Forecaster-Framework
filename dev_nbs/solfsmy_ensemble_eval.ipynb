# %%
# Imports
import sys
sys.path.append('..')
from swdf.benchmark import *
from tsai.basics import *
from sklearn.metrics import mean_squared_error, mean_absolute_error
from swdf.utils import *
import wandb
from swdf.losses import *
from swdf.plots import *
wandb_api = wandb.Api()

# %% [markdown]
# # Evaluation of Solar FSMY 10.7 Ensemble Forecaster
#
# In this notebook, we evaluate the performance of the trained model in comparison to the benchmark established by [Licata et al. (2020)](https://doi.org/10.1029/2020sw002496).

# %%
# Constants
# ARTIFACT_DOWNLOAD_PATH = Path(os.environ["WANDB_DIR"])/"wandb/artifacts/solfsmy_eval_tmp"

# %%
# Config
config = yaml2dict('config/solfsmy_ensemble.yaml')

config
# Out:
# {'data': {'data_url': 'https://sol.spacenvironment.net/JB2008/indices/SOLFSMY.TXT',
#   'data_path': '../data/SOLFSMY.TXT',
#   'force_download': False,
#   'data_nb': './solfsmy_data.ipynb',
#   'df_save_path': './preprocessed_data/dataframes/solfsmy.pkl',
#   'preproc_pipe_save_path': './preprocessed_data/pipelines/preproc_solfsmy.pkl',
#   'exp_pipe_save_path': './preprocessed_data/pipelines/exp_solfsmy.pkl',
#   'data_columns': ['F10', 'S10', 'M10', 'Y10'],
#   'data_time_columns': ['Year', 'DDD'],
#   'add_time_channels': False},
#  'train': {'n_epoch': 30,
#   'partial_n': 0.1,
#   'bs': 32,
#   'lookback': 24,
#   'horizon': 6,
#   'metrics_handler_path': None,
#   'main_metric': 'default',
#   'learner1': {'arch_name': 'PatchTST',
#    'arch_config_file': 'config/patchtst.yaml',
#    'init_weights': False,
#    'lr_max': None,
#    'loss_func': 'wMSE',
#    'loss_config': {}},
#   'learner2': {'arch_name': 'PatchTST',
#    'arch_config_file': 'config/patchtst.yaml',
#    'init_weights': False,
#    'lr_max': None,
#    'loss_func': 'wMAE',
#    'loss_config': {}}},
#  'eval': {'dst_data_path': '../data/DST_IAGA2002.txt',
#   'learner_artifact': None,
#   'round_preds': True,
#   'solfsmy_data_path': '../data/SOLFSMY.TXT'}}

# %%
learner1 = load_learner_all("tmp", model_fname = 'model_learner1', learner_fname="learner_learner1", 
                         verbose=True, 
                         device=default_device())

learner2 = load_learner_all("tmp", model_fname = 'model_learner2', learner_fname="learner_learner2", 
                         verbose=True, 
                         device=default_device())
# Out:
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth']'
# model_fname   = 'model_learner1.pth'
# learner_fname = 'learner_learner1.pkl'
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth']'
# model_fname   = 'model_learner2.pth'
# learner_fname = 'learner_learner2.pkl'

# %%
y_test_preds_learner1, y_test = learner1.get_preds(ds_idx = 2, with_targs=True)
y_test_preds_learner2, _ = learner2.get_preds(ds_idx = 2, with_targs=True) 

y_test_preds = (y_test_preds_learner1 + y_test_preds_learner2) / 2

y_test_preds = to_np(y_test_preds)
y_test = to_np(y_test)
print(f"y_test_preds.shape: {y_test_preds.shape}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# y_test_preds.shape: (2254, 4, 6)

# %%
horizon = y_test.shape[-1]
data_columns_fcst = ['F10', 'S10', 'M10', 'Y10']

# %% [markdown]
# The evaluation is done for each variable separately, for each solar activity
# level (low, moderate, elevated and high), as in the paper by Licata et al. (2020)
# Therefore, the test set has to be split into 4 different sets, one for each solar activity level. The thresholds for each solar activity level are the same as in the paper by Licata et al. (2020)
#
# The thresholds are:
# - F10: 75, 150, 190
# - S10: 65, 150, 215
# - M10: 72, 144, 167
# - Y10: 81, 148, 165

# %%
#|export

def get_idxs_per_solar_activity_level(data, thresholds):
    # function that splits the data of a variable into 4 different sets, 
    # one for each solar activity level. The data comes as a numpy array with 
    # shape (samples, steps), and the split is done along the samples axis. 
    # The decision is made based on the first column of each sample. The function 
    # returns a list of 4 numpy arrays, one for each solar activity level. 
    # But it does not return the values, it returns the indices of the
    # samples that belong to each solar activity level.
    idxs_per_solar_activity_level = []
    for i in range(len(thresholds) + 1):
        if i == 0:
            idxs = np.where(data[:, 0] <= thresholds[i])[0]
        elif i == len(thresholds):
            idxs = np.where(data[:, 0] > thresholds[i-1])[0]
        else:
            idxs = np.where((data[:, 0] > thresholds[i-1]) & (data[:, 0] <= thresholds[i]))[0]
        idxs_per_solar_activity_level.append(idxs)
    return idxs_per_solar_activity_level

# %%
# Call the function for each variable, using y_test
thresholds = {'F10': [75, 150, 190], 
              'S10': [65, 150, 215], 
              'M10': [72, 144, 167], 
              'Y10': [81, 148, 165]}

y_test_split_idxs = {}
for i, var in enumerate(data_columns_fcst):
    y_test_split_idxs[var] = get_idxs_per_solar_activity_level(y_test[:, i, :], 
                                                               thresholds[var])
# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1435,), (205,), (23,)]
# S10: [(496,), (1475,), (283,), (0,)]
# M10: [(529,), (1477,), (223,), (25,)]
# Y10: [(487,), (1666,), (97,), (4,)]

# %%
df_SET = pd.read_pickle('preprocessed_data/dataframes/set_solfsmy.pkl')

_, y_test_SET = SlidingWindow(
            window_len=config.train.lookback,
            horizon=config.train.horizon, 
            stride=1, 
            get_x=['S10'], 
            get_y=['S10']
        )(df_SET)

y_test_split_idxs['S10'] = get_idxs_per_solar_activity_level(y_test_SET, thresholds['S10'])

# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1435,), (205,), (23,)]
# S10: [(520,), (1433,), (267,), (33,)]
# M10: [(529,), (1477,), (223,), (25,)]
# Y10: [(487,), (1666,), (97,), (4,)]

# %%
# Now split y_test and y_test_preds with the idxs we got, using numpy.take
y_test_split = {}
y_test_preds_split = {}
for var in data_columns_fcst:
    y_test_split[var] = [y_test[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]
    y_test_preds_split[var] = [y_test_preds[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]

# Check the shape of each variable in y_test_split
for var in data_columns_fcst:
    print(f"y_test-{var}: {[y_test_split[var][i].shape for i in range(4)]}")
    print(f"y_test_preds-{var}: {[y_test_preds_split[var][i].shape for i in range(4)]}")
# Out:
# y_test-F10: [(591, 6), (1435, 6), (205, 6), (23, 6)]
# y_test_preds-F10: [(591, 6), (1435, 6), (205, 6), (23, 6)]
# y_test-S10: [(520, 6), (1433, 6), (267, 6), (33, 6)]
# y_test_preds-S10: [(520, 6), (1433, 6), (267, 6), (33, 6)]
# y_test-M10: [(529, 6), (1477, 6), (223, 6), (25, 6)]
# y_test_preds-M10: [(529, 6), (1477, 6), (223, 6), (25, 6)]
# y_test-Y10: [(487, 6), (1666, 6), (97, 6), (4, 6)]
# y_test_preds-Y10: [(487, 6), (1666, 6), (97, 6), (4, 6)]

# %%
# Create a table (dataframe) with the mean forecast error for each variable (F10, S10, M10, Y10), 
# each solar activity level and each horizon (1..horizon)
data = []
sals = ['low', 'moderate', 'elevated', 'high']
for var_idx, var in enumerate(data_columns_fcst):
    for sal_idx,sal in enumerate(sals):
        for h in range(1, horizon+1):
            fe_sfu = forecast_error(y_test_split[var][sal_idx], 
                                y_test_preds_split[var][sal_idx], h)
            fe_percent = percent_forecast_error(y_test_split[var][sal_idx],
                                            y_test_preds_split[var][sal_idx], h)
            n_samples = y_test_split[var][sal_idx].shape[0]
            data.append([var, sal, h, np.mean(fe_sfu), np.std(fe_sfu), 
                        np.mean(fe_percent), np.std(fe_percent), n_samples])
df_results = pd.DataFrame(data, columns=['variable', 'condition', 'horizon', 
                                         'mean_sfu', 'std_sfu', 'mean_percent', 
                                         'std_percent', 'n_samples'])
df_results.head(10)
# Out:
#   variable condition  horizon  mean_sfu   std_sfu  mean_percent  std_percent  \
# 0      F10       low        1  0.253184  1.289272      0.360529     1.805295
# 1      F10       low        2  0.239555  1.695057      0.357883     2.349162
# 2      F10       low        3  0.176534  2.183134      0.298104     2.987945
# 3      F10       low        4  0.416489  2.711614      0.659994     3.656886
# 4      F10       low        5  0.225710  3.217510      0.440518     4.245781
# 5      F10       low        6  0.422187  3.735219      0.751909     4.827784
# 6      F10  moderate        1 -0.091003  2.809239     -0.060214     2.383655
# 7      F10  moderate        2 -0.434075  4.415401     -0.288741     3.673837
# 8      F10  moderate        3 -1.078974  5.989987     -0.741014     4.954376
# 9      F10  moderate        4 -0.973813  7.136340     -0.539141     5.889838
#
#    n_samples
# 0        591
# 1        591
# 2        591
# 3        591
# 4        591
# 5        591
# 6       1435
# 7       1435
# 8       1435
# 9       1435

# %%
# Divide the table into one dataframe for each variable, and print it in a way
# that has the same format as the table in the paper, that is:
# Columns: | Condition | Statistics | 1 Day | 2 Days | 3 Days | ... | {{horizon}} Days,
# where condition is the variable and the solar activity level, and statistics 
# is the mean (column mean_fe) and the standard deviation (std_fe) of the forecast error.
for i, var in enumerate(data_columns_fcst):
    df_var = df_results[df_results['variable'] == var]

    df_var = df_var.melt(id_vars=['condition', 'horizon'], 
                         value_vars=['mean_sfu', 'std_sfu'], 
                         var_name='Statistic')
    # Sort the values of the column condition so that the order is 
    # low, moderate, elevated, high
    df_var['condition'] = pd.Categorical(df_var['condition'], 
                                      categories=['low', 'moderate', 'elevated', 'high'], 
                                      ordered=True)
    df_var = df_var.pivot_table(index=['condition', 'Statistic'], 
                          columns='horizon', 
                          values='value')
    # pretty print, and separate with a blank line
    print(f'Distribution Statistics {var} Error Distribution \n{df_var.to_string()}\n')
# Out:
# Distribution Statistics F10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu   0.253184  0.239555  0.176534   0.416489   0.225710   0.422187
#           std_sfu    1.289272  1.695057  2.183134   2.711614   3.217510   3.735219
# moderate  mean_sfu  -0.091003 -0.434075 -1.078974  -0.973813  -1.596152  -1.461858
#           std_sfu    2.809239  4.415401  5.989987   7.136340   8.511149   9.629210
# elevated  mean_sfu  -0.759718 -1.795084 -2.488440  -2.422431  -2.204080  -1.353076
#           std_sfu    3.806529  6.381474  8.684984  10.708257  11.982726  12.614729
# high      mean_sfu  -1.732162 -3.790969 -4.990752  -5.466260  -5.042551  -2.983141
#           std_sfu    3.330431  4.966432  5.670048   6.672052   8.560189  10.103167
#
# Distribution Statistics S10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.005400 -0.185132 -0.036908   0.210262   0.149028   0.218229
#           std_sfu    2.102181  4.655207  3.899760   4.973242   5.637895   7.394747
# moderate  mean_sfu  -0.216933 -0.632952 -1.314400  -1.136884  -1.688093  -1.481914
#           std_sfu    2.733955  4.329385  5.899095   7.088933   8.451400   9.546500
# elevated  mean_sfu   0.727182  0.670765  1.165544   1.255765   1.927248   2.696404
#           std_sfu    2.936905  4.698741  6.456341   8.326802   9.476101  10.121530
# high      mean_sfu  -0.543583 -1.486068 -0.159510   1.016457   0.978106   2.779503
#           std_sfu    3.136542  5.734499  9.071026  10.892224  12.261756  11.105376
#
# Distribution Statistics M10 Error Distribution
# horizon                     1         2         3         4         5          6
# condition Statistic
# low       mean_sfu   0.164868  0.133896  0.098543  0.302277  0.224857   0.418593
#           std_sfu    1.631762  2.314472  3.134487  3.777865  4.281935   4.695961
# moderate  mean_sfu  -0.151239 -0.587172 -1.237719 -1.221420 -1.867430  -1.771828
#           std_sfu    2.745952  4.328070  5.905203  7.065069  8.441605   9.495959
# elevated  mean_sfu  -0.080049  0.340722  0.831021  2.169932  3.445009   4.745105
#           std_sfu    3.681316  5.921073  8.120398  9.442914  9.967013  10.036160
# high      mean_sfu  -0.669766 -2.597964 -2.621135 -1.353727 -0.628953   1.092159
#           std_sfu    2.748639  4.210709  5.289957  6.331815  7.511378   8.647000
#
# Distribution Statistics Y10 Error Distribution
# horizon                     1         2         3         4          5          6
# condition Statistic
# low       mean_sfu   0.217234  0.255780  0.294823  0.492787   0.410023   0.687431
#           std_sfu    1.314196  1.710853  2.065426  2.506679   2.870887   3.144327
# moderate  mean_sfu  -0.196219 -0.569222 -1.243342 -1.089568  -1.659035  -1.451323
#           std_sfu    2.738945  4.307299  5.866873  7.015673   8.353206   9.403682
# elevated  mean_sfu   0.587817  0.722765  0.524243  0.834383   1.631204   2.551371
#           std_sfu    3.238972  5.363894  7.254255  8.268151   9.138694   9.527070
# high      mean_sfu  -8.853832 -5.293850 -3.106297  2.448441   5.835587   7.236065
#           std_sfu    5.962377  4.124740  6.925500  9.800233  11.959331  12.876864

# %%
# Convert df_results into long format
df_results_lf = df_results.melt(id_vars=['variable', 'condition', 'horizon'],
                                value_vars=['mean_sfu', 'std_sfu', 'mean_percent', 'std_percent'],
                                var_name='statistic')

# Filter out the percent statistics
df_results_lf = df_results_lf[df_results_lf['statistic'].str.contains('percent') == False]

# Rename the Statistic 'mean_sfu' to just 'mean' and 'std_sfu' to 'std'
df_results_lf['statistic'] = df_results_lf['statistic'].str.replace('_sfu', '')

df_results_lf.head()
# Out:
#   variable condition  horizon statistic     value
# 0      F10       low        1      mean  0.253184
# 1      F10       low        2      mean  0.239555
# 2      F10       low        3      mean  0.176534
# 3      F10       low        4      mean  0.416489
# 4      F10       low        5      mean  0.225710

# %%
# Compare these results with the results in the paper. The results in the paper
# can be found in the data folder as a csv
df_results_paper = pd.read_csv('../data/paper_results.csv')

# Filter out the rows with Statistics = 'EBM'
df_results_paper = df_results_paper[df_results_paper['statistic'] != 'EBM']

# Rename the values of the column condition to the ones of the sals variable
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Low solar', 'low')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Moderate solar', 'moderate')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Elevated solar', 'elevated')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('High solar', 'high')

df_results_paper.head()
# Out:
#   variable condition statistic   1 Days   2 Days   3 Days   4 Days   5 Days  \
# 0      F10       low      mean  -0.2685  -0.7472  -0.6672  -0.3721  -0.0674
# 1      F10       low       std   3.6985   4.7031   5.5001   6.1683   6.7677
# 3      F10  moderate      mean  -0.8251  -0.8095  -0.9639  -1.1450  -1.1456
# 4      F10  moderate       std  12.0854  14.9853  17.8425  20.2973  21.9353
# 6      F10  elevated      mean   5.7270   7.2425   9.0385  10.3829  11.0017
#
#     6 Days
# 0   0.2428
# 1   7.2050
# 3  -1.1679
# 4  23.3389
# 6  10.9559

# %%
# Convert df_results_paper into long format
df_results_paper_lf = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'],
                                            value_vars=[f'{i} Days' for i in range(1, horizon+1)],
                                            var_name='horizon', value_name='value')

# Convert the value sof the horizon column to int
df_results_paper_lf['horizon'] = df_results_paper_lf['horizon'].str.replace(' Days', '').astype(int)
df_results_paper_lf.head()
# Out:
#   variable condition statistic  horizon    value
# 0      F10       low      mean        1  -0.2685
# 1      F10       low       std        1   3.6985
# 2      F10  moderate      mean        1  -0.8251
# 3      F10  moderate       std        1  12.0854
# 4      F10  elevated      mean        1   5.7270

# %%
# Join the two dataframes (df_results_ours and df_results_paper) on the columns 
# variable, condition and Statistic
df_results_joined = df_results_lf.merge(df_results_paper_lf, how='left', 
                                            on=['variable', 'condition', 'statistic', 'horizon'],
                                            suffixes=('_ours', '_paper'))
len(df_results_lf), len(df_results_paper_lf), len(df_results_joined)
# Out:
# (192, 192, 192)

# %% [markdown]
# ### Visualize predictions

# %%
df_long = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'], 
                      var_name='horizon', value_name='value')

df_long['horizon'] = df_long['horizon'].str.extract('(\d)').astype(int)
    
sfu_stats = df_long.groupby(['variable', 'condition','statistic', 'horizon']).agg(
        values=('value', 'mean')
    ).reset_index()

df_results_paper_formated = sfu_stats[['variable','condition','horizon']].iloc[np.where(sfu_stats['statistic'] == 'mean')]
df_results_paper_formated['std_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] != 'mean')].values
df_results_paper_formated['mean_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] == 'mean')].values
df_results_paper_formated['n_samples'] = np.nan
df_results_paper_formated['mean_sfu'] = np.nan
df_results_paper_formated['std_sfu'] = np.nan

df_results_paper_formated.reset_index()
# Out:
#     index variable condition  horizon  std_percent  mean_percent  n_samples  \
# 0       0      F10  elevated        1      18.3328        5.7270        NaN
# 1       1      F10  elevated        2      22.1021        7.2425        NaN
# 2       2      F10  elevated        3      25.2942        9.0385        NaN
# 3       3      F10  elevated        4      27.0774       10.3829        NaN
# 4       4      F10  elevated        5      27.5279       11.0017        NaN
# ..    ...      ...       ...      ...          ...           ...        ...
# 91    181      Y10  moderate        2      10.1811       -1.3317        NaN
# 92    182      Y10  moderate        3      11.8475       -1.7651        NaN
# 93    183      Y10  moderate        4      13.0170       -2.1734        NaN
# 94    184      Y10  moderate        5      13.8737       -2.5561        NaN
# 95    185      Y10  moderate        6      14.8937       -2.9688        NaN
#
#     mean_sfu  std_sfu
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 91       NaN      NaN
# 92       NaN      NaN
# 93       NaN      NaN
# 94       NaN      NaN
# 95       NaN      NaN
#
# [96 rows x 9 columns]

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'F10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'S10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'M10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'Y10')

# %%
figure = plot_solar_algorithm_performance_all_indices(df_results, df_results_paper_formated, save_fig=True)

# %%
pivoted_df = df_results_joined.pivot_table(index=['variable', 'condition', 'statistic'], 
                            columns='horizon', 
                            values=['value_ours','value_paper'], 
                            aggfunc='first').reset_index()

# To order the columns in the way that we want
condition_order = ['low', 'moderate', 'elevated', 'high']
pivoted_df['condition'] = pd.Categorical(pivoted_df['condition'], categories=condition_order, ordered=True)

# Format columns names
pivoted_df.columns = pd.MultiIndex.from_tuples(
    list(pivoted_df.columns[:3]) + 
    [(value, f'{i} Days Horizon') for value in ['Value Ours', 'Value Benchmark'] for i in range(1,7)]
)

pivoted_df = pivoted_df.sort_values([('variable',''),('condition','')])
pivoted_df.head(1)
# Out:
#   variable condition statistic     Value Ours                                \
#                                1 Days Horizon 2 Days Horizon 3 Days Horizon
# 4      F10       low      mean       0.253184       0.239555       0.176534
#
#                                                Value Benchmark                 \
#   4 Days Horizon 5 Days Horizon 6 Days Horizon  1 Days Horizon 2 Days Horizon
# 4       0.416489        0.22571       0.422187         -0.2685        -0.7472
#
#
#   3 Days Horizon 4 Days Horizon 5 Days Horizon 6 Days Horizon
# 4        -0.6672        -0.3721        -0.0674         0.2428

# %%
def highlight_max(row):
    # Empty color mask
    colors = [''] * len(row)
    columns = ['Value Ours', 'Value Benchmark']
    min_values = []
    
    for i in range(1,7):
        min_values.append(
            min(
                abs(row[('Value Ours', f'{i} Days Horizon')]), 
                abs(row[('Value Benchmark', f'{i} Days Horizon')])
            )
        )
    for i, value in enumerate(row[columns]):
        if np.abs(value) in min_values:
            colors[i+3] = 'background-color: grey'  # The 3 first columns are tags and no data
    return colors

# Compare and highlight # Get max of each element in both dataframes
styled_result = pivoted_df.style.apply(highlight_max, axis=1)

styled_result
# Out:
# <style type="text/css">
# #T_eda2b_row0_col3, #T_eda2b_row0_col4, #T_eda2b_row0_col5, #T_eda2b_row0_col12, #T_eda2b_row0_col13, #T_eda2b_row0_col14, #T_eda2b_row1_col3, #T_eda2b_row1_col4, #T_eda2b_row1_col5, #T_eda2b_row1_col6, #T_eda2b_row1_col7, #T_eda2b_row1_col8, #T_eda2b_row2_col3, #T_eda2b_row2_col4, #T_eda2b_row2_col6, #T_eda2b_row2_col11, #T_eda2b_row2_col13, #T_eda2b_row2_col14, #T_eda2b_row3_col3, #T_eda2b_row3_col4, #T_eda2b_row3_col5, #T_eda2b_row3_col6, #T_eda2b_row3_col7, #T_eda2b_row3_col8, #T_eda2b_row4_col3, #T_eda2b_row4_col4, #T_eda2b_row4_col5, #T_eda2b_row4_col6, #T_eda2b_row4_col7, #T_eda2b_row4_col8, #T_eda2b_row5_col3, #T_eda2b_row5_col4, #T_eda2b_row5_col5, #T_eda2b_row5_col6, #T_eda2b_row5_col7, #T_eda2b_row5_col8, #T_eda2b_row6_col3, #T_eda2b_row6_col4, #T_eda2b_row6_col5, #T_eda2b_row6_col6, #T_eda2b_row6_col7, #T_eda2b_row6_col8, #T_eda2b_row7_col3, #T_eda2b_row7_col4, #T_eda2b_row7_col5, #T_eda2b_row7_col6, #T_eda2b_row7_col7, #T_eda2b_row7_col8, #T_eda2b_row8_col3, #T_eda2b_row8_col4, #T_eda2b_row8_col5, #T_eda2b_row8_col6, #T_eda2b_row8_col7, #T_eda2b_row8_col8, #T_eda2b_row9_col3, #T_eda2b_row9_col4, #T_eda2b_row9_col5, #T_eda2b_row9_col6, #T_eda2b_row9_col7, #T_eda2b_row9_col8, #T_eda2b_row10_col3, #T_eda2b_row10_col4, #T_eda2b_row10_col11, #T_eda2b_row10_col12, #T_eda2b_row10_col13, #T_eda2b_row10_col14, #T_eda2b_row11_col3, #T_eda2b_row11_col4, #T_eda2b_row11_col5, #T_eda2b_row11_col6, #T_eda2b_row11_col7, #T_eda2b_row11_col8, #T_eda2b_row12_col3, #T_eda2b_row12_col4, #T_eda2b_row12_col5, #T_eda2b_row12_col6, #T_eda2b_row12_col7, #T_eda2b_row12_col8, #T_eda2b_row13_col3, #T_eda2b_row13_col4, #T_eda2b_row13_col5, #T_eda2b_row13_col6, #T_eda2b_row13_col7, #T_eda2b_row13_col8, #T_eda2b_row14_col3, #T_eda2b_row14_col4, #T_eda2b_row14_col5, #T_eda2b_row14_col6, #T_eda2b_row14_col7, #T_eda2b_row14_col8, #T_eda2b_row15_col3, #T_eda2b_row15_col4, #T_eda2b_row15_col5, #T_eda2b_row15_col6, #T_eda2b_row15_col7, #T_eda2b_row15_col8, #T_eda2b_row16_col3, #T_eda2b_row16_col5, #T_eda2b_row16_col10, #T_eda2b_row16_col12, #T_eda2b_row16_col13, #T_eda2b_row16_col14, #T_eda2b_row17_col3, #T_eda2b_row17_col4, #T_eda2b_row17_col5, #T_eda2b_row17_col6, #T_eda2b_row17_col7, #T_eda2b_row17_col14, #T_eda2b_row18_col9, #T_eda2b_row18_col10, #T_eda2b_row18_col11, #T_eda2b_row18_col12, #T_eda2b_row18_col13, #T_eda2b_row18_col14, #T_eda2b_row19_col3, #T_eda2b_row19_col4, #T_eda2b_row19_col5, #T_eda2b_row19_col6, #T_eda2b_row19_col7, #T_eda2b_row19_col8, #T_eda2b_row20_col3, #T_eda2b_row20_col4, #T_eda2b_row20_col5, #T_eda2b_row20_col6, #T_eda2b_row20_col7, #T_eda2b_row20_col8, #T_eda2b_row21_col3, #T_eda2b_row21_col4, #T_eda2b_row21_col5, #T_eda2b_row21_col6, #T_eda2b_row21_col7, #T_eda2b_row21_col8, #T_eda2b_row22_col3, #T_eda2b_row22_col4, #T_eda2b_row22_col5, #T_eda2b_row22_col6, #T_eda2b_row22_col7, #T_eda2b_row22_col8, #T_eda2b_row23_col3, #T_eda2b_row23_col4, #T_eda2b_row23_col5, #T_eda2b_row23_col6, #T_eda2b_row23_col7, #T_eda2b_row23_col8, #T_eda2b_row24_col3, #T_eda2b_row24_col10, #T_eda2b_row24_col11, #T_eda2b_row24_col12, #T_eda2b_row24_col13, #T_eda2b_row24_col14, #T_eda2b_row25_col3, #T_eda2b_row25_col4, #T_eda2b_row25_col5, #T_eda2b_row25_col6, #T_eda2b_row25_col7, #T_eda2b_row25_col8, #T_eda2b_row26_col3, #T_eda2b_row26_col4, #T_eda2b_row26_col5, #T_eda2b_row26_col6, #T_eda2b_row26_col7, #T_eda2b_row26_col8, #T_eda2b_row27_col3, #T_eda2b_row27_col4, #T_eda2b_row27_col5, #T_eda2b_row27_col6, #T_eda2b_row27_col7, #T_eda2b_row27_col8, #T_eda2b_row28_col3, #T_eda2b_row28_col4, #T_eda2b_row28_col5, #T_eda2b_row28_col6, #T_eda2b_row28_col7, #T_eda2b_row28_col8, #T_eda2b_row29_col3, #T_eda2b_row29_col4, #T_eda2b_row29_col5, #T_eda2b_row29_col6, #T_eda2b_row29_col7, #T_eda2b_row29_col8, #T_eda2b_row30_col5, #T_eda2b_row30_col6, #T_eda2b_row30_col9, #T_eda2b_row30_col10, #T_eda2b_row30_col13, #T_eda2b_row30_col14, #T_eda2b_row31_col3, #T_eda2b_row31_col4, #T_eda2b_row31_col5, #T_eda2b_row31_col6, #T_eda2b_row31_col13, #T_eda2b_row31_col14 ...
#   background-color: grey;
# }
# </style>
# <table id="T_eda2b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eda2b_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_eda2b_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_eda2b_level0_col2" class="col_heading level0 col2" >statistic</th>
#       <th id="T_eda2b_level0_col3" class="col_heading level0 col3" colspan="6">Value Ours</th>
#       <th id="T_eda2b_level0_col9" class="col_heading level0 col9" colspan="6">Value Benchmark</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_eda2b_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_eda2b_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_eda2b_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_eda2b_level1_col3" class="col_heading level1 col3" >1 Days Horizon</th>
#       <th id="T_eda2b_level1_col4" class="col_heading level1 col4" >2 Days Horizon</th>
#       <th id="T_eda2b_level1_col5" class="col_heading level1 col5" >3 Days Horizon</th>
#       <th id="T_eda2b_level1_col6" class="col_heading level1 col6" >4 Days Horizon</th>
#       <th id="T_eda2b_level1_col7" class="col_heading level1 col7" >5 Days Horizon</th>
#       <th id="T_eda2b_level1_col8" class="col_heading level1 col8" >6 Days Horizon</th>
#       <th id="T_eda2b_level1_col9" class="col_heading level1 col9" >1 Days Horizon</th>
#       <th id="T_eda2b_level1_col10" class="col_heading level1 col10" >2 Days Horizon</th>
#       <th id="T_eda2b_level1_col11" class="col_heading level1 col11" >3 Days Horizon</th>
#       <th id="T_eda2b_level1_col12" class="col_heading level1 col12" >4 Days Horizon</th>
#       <th id="T_eda2b_level1_col13" class="col_heading level1 col13" >5 Days Horizon</th>
#       <th id="T_eda2b_level1_col14" class="col_heading level1 col14" >6 Days Horizon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eda2b_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_eda2b_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_eda2b_row0_col1" class="data row0 col1" >low</td>
#       <td id="T_eda2b_row0_col2" class="data row0 col2" >mean</td>
#       <td id="T_eda2b_row0_col3" class="data row0 col3" >0.253184</td>
#       <td id="T_eda2b_row0_col4" class="data row0 col4" >0.239555</td>
#       <td id="T_eda2b_row0_col5" class="data row0 col5" >0.176534</td>
#       <td id="T_eda2b_row0_col6" class="data row0 col6" >0.416489</td>
#       <td id="T_eda2b_row0_col7" class="data row0 col7" >0.225710</td>
#       <td id="T_eda2b_row0_col8" class="data row0 col8" >0.422187</td>
#       <td id="T_eda2b_row0_col9" class="data row0 col9" >-0.268500</td>
#       <td id="T_eda2b_row0_col10" class="data row0 col10" >-0.747200</td>
#       <td id="T_eda2b_row0_col11" class="data row0 col11" >-0.667200</td>
#       <td id="T_eda2b_row0_col12" class="data row0 col12" >-0.372100</td>
#       <td id="T_eda2b_row0_col13" class="data row0 col13" >-0.067400</td>
#       <td id="T_eda2b_row0_col14" class="data row0 col14" >0.242800</td>
#     </tr>
#     <tr>
#       <th id="T_eda2b_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_eda2b_row1_col0" class="data row1 col0" >F10</td>
#       <td id="T_eda2b_row1_col1" class="data row1 col1" >low</td>
#       <td id="T_eda2b_row1_col2" class="data row1 col2" >std</td>
#       <td id="T_eda2b_row1_col3" class="data row1 col3" >1.289272</td>
#       <td id="T_eda2b_row1_col4" class="data row1 col4" >1.695057</td>
#       <td id="T_eda2b_row1_col5" class="data row1 col5" >2.183134</td>
#       <td id="T_eda2b_row1_col6" class="data row1 col6" >2.711614</td>
#       <td id="T_eda2b_row1_col7" class="data row1 col7" >3.217510</td>
#       <td id="T_eda2b_row1_col8" class="data row1 col8" >3.735219</td>
#       <td id="T_eda2b_row1_col9" class="data row1 col9" >3.698500</td>
#       <td id="T_eda2b_row1_col10" class="data row1 col10" >4.703100</td>
#       <td id="T

# %%
improvement_df = pivoted_df.copy()
for i in range(1, 7):
    improvement_df[f'Improvement {i}'] = (improvement_df[('Value Ours', f'{i} Days Horizon')] - improvement_df[('Value Benchmark', f'{i} Days Horizon')]) / improvement_df[('Value Benchmark', f'{i} Days Horizon')] * 100

overall_mean_improvement = improvement_df.groupby('statistic')[[(f'Improvement {i}','')  for i in range(1, 7)]].mean().mean(axis=1)
variable_mean_improvement = improvement_df.groupby(['variable', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)
condition_mean_improvement = improvement_df.groupby(['condition', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)
var_cond_mean_improvement = improvement_df.groupby(['variable', 'condition', 'statistic'])[[(f'Improvement {i}','') for i in range(1, 7)]].mean().mean(axis=1)

variable_mean_improvement.keys()
# Out:
# MultiIndex([('F10', 'mean'),
#             ('F10',  'std'),
#             ('M10', 'mean'),
#             ('M10',  'std'),
#             ('S10', 'mean'),
#             ('S10',  'std'),
#             ('Y10', 'mean'),
#             ('Y10',  'std')],
#            names=['variable', 'statistic'])

# %%
aligned_series1 = pd.Series(overall_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [('', 'overall', 'mean'), ('', 'overall', 'std')], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )
aligned_series2 = pd.Series(variable_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [(key[0],) + ('',) + (key[1],)  for key in variable_mean_improvement.keys()], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )
aligned_series3 = pd.Series(condition_mean_improvement.values, 
                            index=pd.MultiIndex.from_tuples(
                                [('',) + key for key in condition_mean_improvement.keys()], 
                                names=['variable', 'condition', 'statistic']
                                )
                            )

# Concatenate the aligned series
performance_comparison_df = pd.DataFrame(pd.concat([aligned_series1, aligned_series2, aligned_series3, var_cond_mean_improvement], axis=0), columns=['Improvement'])
performance_comparison_df.dropna(inplace=True)

# %%
def color_gradient(val, df=performance_comparison_df):
    max_val = df['Improvement'].max()
    min_val = df['Improvement'].min()
    range_val = np.abs(max_val - min_val)
    normalized_val = np.abs(val - min_val) / range_val
    
    red = int(255 * normalized_val)
    green = int(255 * (1 - normalized_val))
    
    return f'background-color: rgb({red},{green},0); color: black'

styled_df = performance_comparison_df.style.applymap(color_gradient, subset=['Improvement'])
styled_df
# Out:
# <style type="text/css">
# #T_4eda0_row0_col0 {
#   background-color: rgb(195,59,0);
#   color: black;
# }
# #T_4eda0_row1_col0, #T_4eda0_row5_col0, #T_4eda0_row15_col0, #T_4eda0_row29_col0, #T_4eda0_row46_col0 {
#   background-color: rgb(227,27,0);
#   color: black;
# }
# #T_4eda0_row2_col0 {
#   background-color: rgb(203,51,0);
#   color: black;
# }
# #T_4eda0_row3_col0, #T_4eda0_row21_col0 {
#   background-color: rgb(221,33,0);
#   color: black;
# }
# #T_4eda0_row4_col0 {
#   background-color: rgb(217,37,0);
#   color: black;
# }
# #T_4eda0_row6_col0 {
#   background-color: rgb(141,113,0);
#   color: black;
# }
# #T_4eda0_row7_col0, #T_4eda0_row13_col0, #T_4eda0_row19_col0, #T_4eda0_row37_col0 {
#   background-color: rgb(226,28,0);
#   color: black;
# }
# #T_4eda0_row8_col0, #T_4eda0_row39_col0 {
#   background-color: rgb(220,34,0);
#   color: black;
# }
# #T_4eda0_row9_col0 {
#   background-color: rgb(234,20,0);
#   color: black;
# }
# #T_4eda0_row10_col0 {
#   background-color: rgb(194,60,0);
#   color: black;
# }
# #T_4eda0_row11_col0 {
#   background-color: rgb(231,23,0);
#   color: black;
# }
# #T_4eda0_row12_col0 {
#   background-color: rgb(183,71,0);
#   color: black;
# }
# #T_4eda0_row14_col0 {
#   background-color: rgb(204,50,0);
#   color: black;
# }
# #T_4eda0_row16_col0 {
#   background-color: rgb(200,54,0);
#   color: black;
# }
# #T_4eda0_row17_col0, #T_4eda0_row43_col0 {
#   background-color: rgb(224,30,0);
#   color: black;
# }
# #T_4eda0_row18_col0 {
#   background-color: rgb(172,82,0);
#   color: black;
# }
# #T_4eda0_row20_col0 {
#   background-color: rgb(247,7,0);
#   color: black;
# }
# #T_4eda0_row22_col0 {
#   background-color: rgb(196,58,0);
#   color: black;
# }
# #T_4eda0_row23_col0, #T_4eda0_row33_col0 {
#   background-color: rgb(222,32,0);
#   color: black;
# }
# #T_4eda0_row24_col0, #T_4eda0_row26_col0, #T_4eda0_row32_col0, #T_4eda0_row48_col0 {
#   background-color: rgb(198,56,0);
#   color: black;
# }
# #T_4eda0_row25_col0, #T_4eda0_row30_col0, #T_4eda0_row41_col0 {
#   background-color: rgb(216,38,0);
#   color: black;
# }
# #T_4eda0_row27_col0 {
#   background-color: rgb(230,24,0);
#   color: black;
# }
# #T_4eda0_row28_col0 {
#   background-color: rgb(255,0,0);
#   color: black;
# }
# #T_4eda0_row31_col0 {
#   background-color: rgb(228,26,0);
#   color: black;
# }
# #T_4eda0_row34_col0 {
#   background-color: rgb(182,72,0);
#   color: black;
# }
# #T_4eda0_row35_col0 {
#   background-color: rgb(243,11,0);
#   color: black;
# }
# #T_4eda0_row36_col0 {
#   background-color: rgb(0,255,0);
#   color: black;
# }
# #T_4eda0_row38_col0 {
#   background-color: rgb(177,77,0);
#   color: black;
# }
# #T_4eda0_row40_col0 {
#   background-color: rgb(206,48,0);
#   color: black;
# }
# #T_4eda0_row42_col0 {
#   background-color: rgb(225,29,0);
#   color: black;
# }
# #T_4eda0_row44_col0, #T_4eda0_row45_col0 {
#   background-color: rgb(229,25,0);
#   color: black;
# }
# #T_4eda0_row47_col0 {
#   background-color: rgb(237,17,0);
#   color: black;
# }
# #T_4eda0_row49_col0 {
#   background-color: rgb(244,10,0);
#   color: black;
# }
# </style>
# <table id="T_4eda0">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4eda0_level0_col0" class="col_heading level0 col0" >Improvement</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="index_name level1" >condition</th>
#       <th class="index_name level2" >statistic</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4eda0_level0_row0" class="row_heading level0 row0" rowspan="2"></th>
#       <th id="T_4eda0_level1_row0" class="row_heading level1 row0" rowspan="2">overall</th>
#       <th id="T_4eda0_level2_row0" class="row_heading level2 row0" >mean</th>
#       <td id="T_4eda0_row0_col0" class="data row0 col0" >-121.975837</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row1" class="row_heading level2 row1" >std</th>
#       <td id="T_4eda0_row1_col0" class="data row1 col0" >-54.758357</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row2" class="row_heading level0 row2" rowspan="2">F10</th>
#       <th id="T_4eda0_level1_row2" class="row_heading level1 row2" rowspan="2"></th>
#       <th id="T_4eda0_level2_row2" class="row_heading level2 row2" >mean</th>
#       <td id="T_4eda0_row2_col0" class="data row2 col0" >-105.173822</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row3" class="row_heading level2 row3" >std</th>
#       <td id="T_4eda0_row3_col0" class="data row3 col0" >-66.608779</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row4" class="row_heading level0 row4" rowspan="2">M10</th>
#       <th id="T_4eda0_level1_row4" class="row_heading level1 row4" rowspan="2"></th>
#       <th id="T_4eda0_level2_row4" class="row_heading level2 row4" >mean</th>
#       <td id="T_4eda0_row4_col0" class="data row4 col0" >-76.635943</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row5" class="row_heading level2 row5" >std</th>
#       <td id="T_4eda0_row5_col0" class="data row5 col0" >-55.581376</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row6" class="row_heading level0 row6" rowspan="2">S10</th>
#       <th id="T_4eda0_level1_row6" class="row_heading level1 row6" rowspan="2"></th>
#       <th id="T_4eda0_level2_row6" class="row_heading level2 row6" >mean</th>
#       <td id="T_4eda0_row6_col0" class="data row6 col0" >-236.855654</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row7" class="row_heading level2 row7" >std</th>
#       <td id="T_4eda0_row7_col0" class="data row7 col0" >-55.922864</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row8" class="row_heading level0 row8" rowspan="2">Y10</th>
#       <th id="T_4eda0_level1_row8" class="row_heading level1 row8" rowspan="2"></th>
#       <th id="T_4eda0_level2_row8" class="row_heading level2 row8" >mean</th>
#       <td id="T_4eda0_row8_col0" class="data row8 col0" >-69.237930</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row9" class="row_heading level2 row9" >std</th>
#       <td id="T_4eda0_row9_col0" class="data row9 col0" >-40.920410</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row10" class="row_heading level0 row10" rowspan="8"></th>
#       <th id="T_4eda0_level1_row10" class="row_heading level1 row10" rowspan="2">low</th>
#       <th id="T_4eda0_level2_row10" class="row_heading level2 row10" >mean</th>
#       <td id="T_4eda0_row10_col0" class="data row10 col0" >-123.945450</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row11" class="row_heading level2 row11" >std</th>
#       <td id="T_4eda0_row11_col0" class="data row11 col0" >-46.773931</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level1_row12" class="row_heading level1 row12" rowspan="2">moderate</th>
#       <th id="T_4eda0_level2_row12" class="row_heading level2 row12" >mean</th>
#       <td id="T_4eda0_row12_col0" class="data row12 col0" >-148.859294</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row13" class="row_heading level2 row13" >std</th>
#       <td id="T_4eda0_row13_col0" class="data row13 col0" >-57.020272</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level1_row14" class="row_heading level1 row14" rowspan="2">elevated</th>
#       <th id="T_4eda0_level2_row14" class="row_heading level2 row14" >mean</th>
#       <td id="T_4eda0_row14_col0" class="data row14 col0" >-103.315540</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row15" class="row_heading level2 row15" >std</th>
#       <td id="T_4eda0_row15_col0" class="data row15 col0" >-55.106886</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level1_row16" class="row_heading level1 row16" rowspan="2">high</th>
#       <th id="T_4eda0_level2_row16" class="row_heading level2 row16" >mean</th>
#       <td id="T_4eda0_row16_col0" class="data row16 col0" >-111.783064</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level2_row17" class="row_heading level2 row17" >std</th>
#       <td id="T_4eda0_row17_col0" class="data row17 col0" >-60.132340</td>
#     </tr>
#     <tr>
#       <th id="T_4eda0_level0_row18" class="row_heading level0 row18" rowspan="8">F10</th>
#       <th id="T_4eda0_level1_row18" class="row_heading level1 row18" rowspan="2">low</th>
#       <th id="T_4eda0_level2_row18" class="row_head

# %%
create_latex_comparison_tables(df_results_joined, data_columns_fcst, horizon)
# Out:
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable F10}
# \label{tab:comparison_F10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{0.2531845} ± \textbf{1.2892721} & -0.2685 ± 3.6985 \\
# low & 2 & \textbf{0.23955491} ± \textbf{1.6950568} & -0.7472 ± 4.7031 \\
# low & 3 & \textbf{0.17653422} ± \textbf{2.183134} & -0.6672 ± 5.5001 \\
# low & 4 & 0.41648918 ± \textbf{2.711614} & \textbf{-0.3721} ± 6.1683 \\
# low & 5 & 0.2257096 ± \textbf{3.2175102} & \textbf{-0.0674} ± 6.7677 \\
# low & 6 & 0.4221873 ± \textbf{3.7352185} & \textbf{0.2428} ± 7.205 \\
# moderate & 1 & \textbf{-0.09100289} ± \textbf{2.8092394} & -0.8251 ± 12.0854 \\
# moderate & 2 & \textbf{-0.43407473} ± \textbf{4.415401} & -0.8095 ± 14.9853 \\
# moderate & 3 & -1.0789742 ± \textbf{5.9899874} & \textbf{-0.9639} ± 17.8425 \\
# moderate & 4 & \textbf{-0.9738126} ± \textbf{7.1363397} & -1.145 ± 20.2973 \\
# moderate & 5 & -1.5961517 ± \textbf{8.511149} & \textbf{-1.1456} ± 21.9353 \\
# moderate & 6 & -1.4618583 ± \textbf{9.62921} & \textbf{-1.1679} ± 23.3389 \\
# elevated & 1 & \textbf{-0.7597184} ± \textbf{3.8065293} & 5.727 ± 18.3328 \\
# elevated & 2 & \textbf{-1.7950835} ± \textbf{6.381474} & 7.2425 ± 22.1021 \\
# elevated & 3 & \textbf{-2.4884403} ± \textbf{8.684984} & 9.0385 ± 25.2942 \\
# elevated & 4 & \textbf{-2.4224305} ± \textbf{10.708257} & 10.3829 ± 27.0774 \\
# elevated & 5 & \textbf{-2.2040803} ± \textbf{11.982726} & 11.0017 ± 27.5279 \\
# elevated & 6 & \textbf{-1.3530759} ± \textbf{12.614729} & 10.9559 ± 26.9074 \\
# high & 1 & \textbf{-1.7321618} ± \textbf{3.3304307} & 15.7448 ± 20.2227 \\
# high & 2 & \textbf{-3.7909691} ± \textbf{4.966432} & 19.5749 ± 24.7236 \\
# high & 3 & \textbf{-4.9907517} ± \textbf{5.670048} & 24.2444 ± 27.6092 \\
# high & 4 & \textbf{-5.46626} ± \textbf{6.6720524} & 26.6674 ± 30.8869 \\
# high & 5 & \textbf{-5.0425506} ± \textbf{8.560189} & 26.023 ± 33.9069 \\
# high & 6 & \textbf{-2.983141} ± \textbf{10.103167} & 23.9778 ± 35.9795 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable S10}
# \label{tab:comparison_S10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.005399601} ± \textbf{2.1021807} & 0.2206 ± 5.8378 \\
# low & 2 & -0.1851322 ± \textbf{4.6552067} & \textbf{-0.0343} ± 5.7474 \\
# low & 3 & \textbf{-0.036908004} ± \textbf{3.8997598} & -0.1044 ± 5.8682 \\
# low & 4 & 0.21026154 ± \textbf{4.9732423} & \textbf{-0.0985} ± 6.0709 \\
# low & 5 & 0.14902787 ± \textbf{5.6378946} & \textbf{-0.066} ± 6.1153 \\
# low & 6 & 0.21822867 ± 7.3947473 & \textbf{-0.0501} ± \textbf{6.0475} \\
# moderate & 1 & -0.2169326 ± \textbf{2.733955} & \textbf{0.1111} ± 10.0715 \\
# moderate & 2 & -0.6329522 ± \textbf{4.329385} & \textbf{0.219} ± 11.7059 \\
# moderate & 3 & -1.3144002 ± \textbf{5.899095} & \textbf{0.2974} ± 13.5434 \\
# moderate & 4 & -1.1368836 ± \textbf{7.0889335} & \textbf{0.3426} ± 14.9844 \\
# moderate & 5 & -1.688093 ± \textbf{8.4514} & \textbf{0.2977} ± 16.1132 \\
# moderate & 6 & -1.481914 ± \textbf{9.5465} & \textbf{0.1862} ± 17.1467 \\
# elevated & 1 & \textbf{0.7271823} ± \textbf{2.936905} & -1.1311 ± 16.5592 \\
# elevated & 2 & \textbf{0.6707649} ± \textbf{4.6987414} & -1.7989 ± 19.205 \\
# elevated & 3 & \textbf{1.1655436} ± \textbf{6.4563413} & -2.2361 ± 21.9271 \\
# elevated & 4 & \textbf{1.2557647} ± \textbf{8.326802} & -2.691 ± 24.1118 \\
# elevated & 5 & \textbf{1.9272479} ± \textbf{9.476101} & -2.8148 ± 25.8017 \\
# elevated & 6 & \textbf{2.6964037} ± \textbf{10.12153} & -2.7593 ± 27.2658 \\
# high & 1 & \textbf{-0.54358256} ± \textbf{3.1365423} & 16.204 ± 35.3267 \\
# high & 2 & \textbf{-1.4860675} ± \textbf{5.7344985} & 23.1628 ± 39.6577 \\
# high & 3 & \textbf{-0.15951006} ± \textbf{9.071026} & 28.3943 ± 39.6471 \\
# high & 4 & \textbf{1.0164566} ± \textbf{10.892224} & 31.4085 ± 38.7875 \\
# high & 5 & \textbf{0.9781057} ± \textbf{12.261756} & 31.6158 ± 38.5307 \\
# high & 6 & \textbf{2.7795026} ± \textbf{11.105376} & 30.1409 ± 38.6613 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable M10}
# \label{tab:comparison_M10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{0.16486809} ± \textbf{1.6317624} & -0.9582 ± 5.1317 \\
# low & 2 & \textbf{0.13389616} ± \textbf{2.3144717} & -1.1063 ± 5.6375 \\
# low & 3 & \textbf{0.09854299} ± \textbf{3.1344872} & -1.2667 ± 6.225 \\
# low & 4 & \textbf{0.30227658} ± \textbf{3.777865} & -1.4203 ± 6.4693 \\
# low & 5 & \textbf{0.22485675} ± \textbf{4.281935} & -1.5303 ± 6.8538 \\
# low & 6 & \textbf{0.41859344} ± \textbf{4.6959615} & -1.6171 ± 7.2024 \\
# moderate & 1 & \textbf{-0.15123874} ± \textbf{2.7459521} & -0.5138 ± 8.9027 \\
# moderate & 2 & \textbf{-0.5871717} ± \textbf{4.3280697} & -0.7424 ± 11.2745 \\
# moderate & 3 & -1.2377187 ± \textbf{5.905203} & \textbf{-0.9976} ± 13.4329 \\
# moderate & 4 & -1.22142 ± \textbf{7.0650687} & \textbf{-1.1619} ± 15.1962 \\
# moderate & 5 & -1.8674302 ± \textbf{8.441605} & \textbf{-1.237} ± 16.4221 \\
# moderate & 6 & -1.7718284 ± \textbf{9.495959} & \textbf{-1.3348} ± 17.4041 \\
# elevated & 1 & \textbf{-0.08004884} ± \textbf{3.6813164} & 3.7282 ± 10.4528 \\
# elevated & 2 & \textbf{0.34072164} ± \textbf{5.921073} & 5.6301 ± 13.4784 \\
# elevated & 3 & \textbf{0.83102065} ± \textbf{8.120398} & 7.3375 ± 16.1156 \\
# elevated & 4 & \textbf{2.1699317} ± \textbf{9.442914} & 8.5258 ± 17.9805 \\
# elevated & 5 & \textbf{3.445009} ± \textbf{9.967013} & 9.0192 ± 18.9175 \\
# elevated & 6 & \textbf{4.7451053} ± \textbf{10.0361595} & 8.9334 ± 19.077 \\
# high & 1 & \textbf{-0.66976625} ± \textbf{2.7486386} & 4.6517 ± 9.2079 \\
# high & 2 & \textbf{-2.5979638} ± \textbf{4.2107086} & 6.3966 ± 12.7892 \\
# high & 3 & \textbf{-2.6211352} ± \textbf{5.2899566} & 8.8328 ± 16.4932 \\
# high & 4 & \textbf{-1.3537269} ± \textbf{6.3318152} & 10.95 ± 19.2241 \\
# high & 5 & \textbf{-0.6289526} ± \textbf{7.511378} & 12.3435 ± 20.913 \\
# high & 6 & \textbf{1.0921592} ± \textbf{8.647} & 12.9784 ± 21.582 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable Y10}
# \label{tab:comparison_Y10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{0.21723418} ± \textbf{1.314196} & -0.427 ± 4.5093 \\
# low & 2 & 0.25577953 ± \textbf{1.7108532} & \textbf{-0.2282} ± 4.9373 \\
# low & 3 & 0.29482323 ± \textbf{2.065426} & \textbf{-0.0684} ± 5.4416 \\
# low & 4 & 0.492787 ± \textbf{2.5066786} & \textbf{0.0902} ± 5.9977 \\
# low & 5 & 0.41002297 ± \textbf{2.8708873} & \textbf{0.2697} ± 6.4255 \\
# low & 6 & 0.68743086 ± \textbf{3.1443267} & \textbf{0.465} ± 6.816 \\
# moderate & 1 & \textbf{-0.19621938} ± \textbf{2.738945} & -0.8277 ± 8.5137 \\
# moderate & 2 & \textbf{-0.5692223} ± \textbf{4.307299} & -1.3317 ± 10.1811 \\
# moderate & 3 & \textbf{-1.2433417} ± \textbf{5.8668733} & -1.7651 ± 11.8475 \\
# moderate & 4 & \textbf{-1.0895677} ± \textbf{7.015673} & -2.1734 ± 13.017 \\
# moderate & 5 & \textbf{-1.6590353} ± \textbf{8.353206} & -2.5561 ± 13.8737 \\
# moderate & 6 & \textbf{-1.4513227} ± \textbf{9.403682} & -2.9688 ± 14.8937 \\
# elevated & 1 & \textbf{0.58781654} ± \textbf{3.2389724} & 2.1089 ± 7.7173 \\
# elevated & 2 & \textbf{0.72276527} ± \textbf{5.3638935} & 1.7243 ± 9.3066 \\
# elevated & 3 & \textbf{0.524243} ± \textbf{7.2542553} & 2.0679 ± 10.6086 \\
# elevated & 4 & \textbf{0.8343829} ± \textbf{8.268151} & 2.5656 ± 11.4955 \\
# elevated & 5 & \textbf{1.6312042} ± \textbf{9.138694} & 2.7714 ± 11.8996 \\
# elevated & 6 & \textbf{2.5513709} ± \textbf{9.52707} & 2.8423 ± 11.9965 \\
# high & 1 & -8.853832 ± \textbf{5.9623766} & \textbf{5.2729} ± 8.5806 \\
# high & 2 & -5.29385 ± \textbf{4.1247396} & \textbf{4.2075} ± 10.8097 \\
# high & 3 & \textbf{-3.1062965} ± \textbf{6.9255} & 4.5855 ± 11.5436 \\
# high & 4 & \textbf{2.4484406} ± \textbf{9.800233} & 5.2131 ± 11.3048 \\
# high & 5 & 5.8355865 ± 11.959331 & \textbf{5.6561} ± \textbf{11.019} \\
# high & 6 & 7.236065 ± 12.876864 & \textbf{6.014} ± \textbf{10.4416} \\
# \bottomrule
# \end{tabular}
# \end{table}
