# %% [markdown]
# # Evaluation of SOLFSMY
#
# > With respect to the benchmark by Licata et al.

# %%
# Imports
import sys
sys.path.append('..')
from swdf.benchmark import *
from tsai.basics import *
from sklearn.metrics import mean_squared_error, mean_absolute_error
from swdf.utils import *
import wandb
from swdf.losses import *
wandb_api = wandb.Api()

# %%
# Constants
# ARTIFACT_DOWNLOAD_PATH = Path(os.environ["WANDB_DIR"])/"wandb/artifacts/solfsmy_eval_tmp"

# %%
# Config
config = yaml2dict('config/solfsmy.yaml')
config = config.eval

config_base = yaml2dict('config/base.yaml')

config, config_base
# Out:
# ({'dst_data_path': '../data/DST_IAGA2002.txt',
#   'learner_artifact': None,
#   'round_preds': True,
#   'solfsmy_data_path': '../data/SOLFSMY.TXT'},
#  {'arch_name': 'PatchTST',
#   'arch_config_file': 'config/patchtst.yaml',
#   'bs': 1024,
#   'horizon': 6,
#   'init_weights': False,
#   'lookback': 36,
#   'lr_max': None,
#   'n_epoch': 30,
#   'partial_n': 0.1,
#   'seed': 42,
#   'test_start_datetime': '2012-10-01 12:00:00',
#   'test_end_datetime': '2018-12-31 12:00:00',
#   'wandb': {'enabled': False,
#    'log_learner': True,
#    'mode': 'offline',
#    'group': None,
#    'project': 'swdf'}})

# %%
learn_wMAE = load_learner_all("tmp", model_fname = 'model_wMAE', learner_fname="learner_wMAE", 
                         verbose=True, 
                         device=default_device())

learn_wMSE = load_learner_all("tmp", model_fname = 'model_wMSE', learner_fname="learner_wMSE", 
                         verbose=True, 
                         device=default_device())
# Out:
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth']'
# model_fname   = 'model_wMAE.pth'
# learner_fname = 'learner_wMAE.pkl'
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth']'
# model_fname   = 'model_wMSE.pth'
# learner_fname = 'learner_wMSE.pkl'

# %%
y_test_preds_wMAE, y_test = learn_wMAE.get_preds(ds_idx = 2, with_targs=True)
y_test_preds_wMSE, _ = learn_wMSE.get_preds(ds_idx = 2, with_targs=True) 

y_test_preds = (y_test_preds_wMAE + y_test_preds_wMSE) / 2

y_test_preds = to_np(y_test_preds)
y_test = to_np(y_test)
print(f"y_test_preds.shape: {y_test_preds.shape}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# y_test_preds.shape: (2242, 4, 6)

# %%
horizon = y_test.shape[-1]
data_columns_fcst = ['F10', 'S10', 'M10', 'Y10']

# %% [markdown]
# The evaluation is done for each variable separately, for each solar activity
# level (low, moderate, elevated and high), as in the paper by Licata et al. (2020)
# Therefore, the test set has to be split into 4 different sets, one for each solar activity level. The thresholds for each solar activity level are the same as in the paper by Licata et al. (2020)
#
# The thresholds are:
# - F10: 75, 150, 190
# - S10: 65, 150, 215
# - M10: 72, 144, 167
# - Y10: 81, 148, 165

# %%
#|export

def get_idxs_per_solar_activity_level(data, thresholds):
    # function that splits the data of a variable into 4 different sets, 
    # one for each solar activity level. The data comes as a numpy array with 
    # shape (samples, steps), and the split is done along the samples axis. 
    # The decision is made based on the first column of each sample. The function 
    # returns a list of 4 numpy arrays, one for each solar activity level. 
    # But it does not return the values, it returns the indices of the
    # samples that belong to each solar activity level.
    idxs_per_solar_activity_level = []
    for i in range(len(thresholds) + 1):
        if i == 0:
            idxs = np.where(data[:, 0] <= thresholds[i])[0]
        elif i == len(thresholds):
            idxs = np.where(data[:, 0] > thresholds[i-1])[0]
        else:
            idxs = np.where((data[:, 0] > thresholds[i-1]) & (data[:, 0] <= thresholds[i]))[0]
        idxs_per_solar_activity_level.append(idxs)
    return idxs_per_solar_activity_level

# %%
# Call the function for each variable, using y_test
thresholds = {'F10': [75, 150, 190], 
              'S10': [65, 150, 215], 
              'M10': [72, 144, 167], 
              'Y10': [81, 148, 165]}

y_test_split_idxs = {}
for i, var in enumerate(data_columns_fcst):
    y_test_split_idxs[var] = get_idxs_per_solar_activity_level(y_test[:, i, :], 
                                                               thresholds[var])
# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(494,), (1465,), (283,), (0,)]
# M10: [(535,), (1442,), (235,), (30,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
df_SET = pd.read_pickle('preprocessed_data/dataframes/set_solfsmy.pkl')

_, y_test_SET = SlidingWindow(
            window_len=config_base.lookback,
            horizon=config_base.horizon, 
            stride=1, 
            get_x=['S10'], 
            get_y=['S10']
        )(df_SET)

y_test_split_idxs['S10'] = get_idxs_per_solar_activity_level(y_test_SET, thresholds['S10'])

# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(520,), (1421,), (267,), (33,)]
# M10: [(535,), (1442,), (235,), (30,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
# Now split y_test and y_test_preds with the idxs we got, using numpy.take
y_test_split = {}
y_test_preds_split = {}
for var in data_columns_fcst:
    y_test_split[var] = [y_test[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]
    y_test_preds_split[var] = [y_test_preds[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]

# Check the shape of each variable in y_test_split
for var in data_columns_fcst:
    print(f"y_test-{var}: {[y_test_split[var][i].shape for i in range(4)]}")
    print(f"y_test_preds-{var}: {[y_test_preds_split[var][i].shape for i in range(4)]}")
# Out:
# y_test-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test_preds-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test_preds-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test-M10: [(535, 6), (1442, 6), (235, 6), (30, 6)]
# y_test_preds-M10: [(535, 6), (1442, 6), (235, 6), (30, 6)]
# y_test-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]
# y_test_preds-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]

# %%
# Create a table (dataframe) with the mean forecast error for each variable (F10, S10, M10, Y10), 
# each solar activity level and each horizon (1..horizon)
data = []
sals = ['low', 'moderate', 'elevated', 'high']
for var_idx, var in enumerate(data_columns_fcst):
    for sal_idx,sal in enumerate(sals):
        for h in range(1, horizon+1):
            fe_sfu = forecast_error(y_test_split[var][sal_idx], 
                                y_test_preds_split[var][sal_idx], h)
            fe_percent = percent_forecast_error(y_test_split[var][sal_idx],
                                            y_test_preds_split[var][sal_idx], h)
            n_samples = y_test_split[var][sal_idx].shape[0]
            data.append([var, sal, h, np.mean(fe_sfu), np.std(fe_sfu), 
                        np.mean(fe_percent), np.std(fe_percent), n_samples])
df_results = pd.DataFrame(data, columns=['variable', 'condition', 'horizon', 
                                         'mean_sfu', 'std_sfu', 'mean_percent', 
                                         'std_percent', 'n_samples'])
df_results.head(10)
# Out:
#   variable condition  horizon  mean_sfu   std_sfu  mean_percent  std_percent  \
# 0      F10       low        1 -0.302316  1.545831     -0.417859     2.158115
# 1      F10       low        2 -0.583242  2.005722     -0.786647     2.758468
# 2      F10       low        3 -0.849308  2.444186     -1.127503     3.304847
# 3      F10       low        4 -0.917582  2.878991     -1.185968     3.825139
# 4      F10       low        5 -1.263246  3.406800     -1.606138     4.399340
# 5      F10       low        6 -1.387918  3.805427     -1.712542     4.745471
# 6      F10  moderate        1 -1.964549  3.937923     -1.646046     3.238343
# 7      F10  moderate        2 -2.685582  5.418038     -2.211299     4.399880
# 8      F10  moderate        3 -2.864855  6.625150     -2.242760     5.317075
# 9      F10  moderate        4 -3.645295  7.953461     -2.823409     6.349705
#
#    n_samples
# 0        591
# 1        591
# 2        591
# 3        591
# 4        591
# 5        591
# 6       1423
# 7       1423
# 8       1423
# 9       1423

# %%
# Divide the table into one dataframe for each variable, and print it in a way
# that has the same format as the table in the paper, that is:
# Columns: | Condition | Statistics | 1 Day | 2 Days | 3 Days | ... | {{horizon}} Days,
# where condition is the variable and the solar activity level, and statistics 
# is the mean (column mean_fe) and the standard deviation (std_fe) of the forecast error.
for i, var in enumerate(data_columns_fcst):
    df_var = df_results[df_results['variable'] == var]

    df_var = df_var.melt(id_vars=['condition', 'horizon'], 
                         value_vars=['mean_sfu', 'std_sfu'], 
                         var_name='Statistic')
    # Sort the values of the column condition so that the order is 
    # low, moderate, elevated, high
    df_var['condition'] = pd.Categorical(df_var['condition'], 
                                      categories=['low', 'moderate', 'elevated', 'high'], 
                                      ordered=True)
    df_var = df_var.pivot_table(index=['condition', 'Statistic'], 
                          columns='horizon', 
                          values='value')
    # pretty print, and separate with a blank line
    print(f'Distribution Statistics {var} Error Distribution \n{df_var.to_string()}\n')
# Out:
# Distribution Statistics F10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.302316 -0.583242 -0.849308  -0.917582  -1.263246  -1.387918
#           std_sfu    1.545831  2.005722  2.444186   2.878991   3.406800   3.805427
# moderate  mean_sfu  -1.964549 -2.685582 -2.864855  -3.645295  -3.956457  -5.111341
#           std_sfu    3.937923  5.418038  6.625150   7.953461   8.996822  10.247547
# elevated  mean_sfu  -5.073747 -6.680293 -8.271734  -9.307090 -10.227098  -9.636679
#           std_sfu    4.965025  7.393454  9.724627  11.358914  12.064628  12.775860
# high      mean_sfu  -3.994943 -5.577252 -6.872797  -7.453322  -7.080386  -5.439536
#           std_sfu    4.771769  6.140223  6.360924   6.947478   8.527883   9.403990
#
# Distribution Statistics S10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.850994 -1.348093 -1.550084  -1.749999  -2.123064  -2.280940
#           std_sfu    2.608296  5.197949  4.394403   5.089952   5.706548   7.440813
# moderate  mean_sfu  -2.124494 -2.874075 -3.176496  -3.778816  -4.192246  -5.418996
#           std_sfu    3.928020  5.374636  6.629379   7.843639   8.978600  10.389380
# elevated  mean_sfu  -2.497599 -3.195631 -4.302513  -5.094389  -5.878284  -6.200410
#           std_sfu    4.224321  6.164845  7.908289   9.539131  10.176993  10.651926
# high      mean_sfu  -3.239697 -4.060820 -3.640510  -2.563244  -2.507215  -1.990838
#           std_sfu    3.872902  5.952044  9.236991  11.282063  12.799155  12.595369
#
# Distribution Statistics M10 Error Distribution
# horizon                     1         2          3          4          5          6
# condition Statistic
# low       mean_sfu  -0.454106 -0.703500  -0.989599  -1.079743  -1.357645  -1.427233
#           std_sfu    1.838706  2.537791   3.268845   3.875091   4.271489   4.531490
# moderate  mean_sfu  -1.988548 -2.782693  -3.017058  -3.918078  -4.307745  -5.478997
#           std_sfu    3.898245  5.351664   6.591473   7.911378   9.027927  10.366497
# elevated  mean_sfu  -4.350334 -4.746852  -4.937865  -4.761235  -5.052602  -3.985266
#           std_sfu    5.159523  7.723948  10.018027  11.088537  11.477722  11.517286
# high      mean_sfu  -2.903821 -3.493287  -3.640615  -2.707524  -2.143100  -0.708627
#           std_sfu    3.591857  4.714830   5.929944   6.704160   7.021248   7.961961
#
# Distribution Statistics Y10 Error Distribution
# horizon                      1         2         3          4          5          6
# condition Statistic
# low       mean_sfu   -0.322247 -0.522043 -0.774743  -0.794261  -1.061835  -1.083294
#           std_sfu     1.536759  1.937413  2.300825   2.621149   3.007267   3.063972
# moderate  mean_sfu   -2.062421 -2.806844 -3.077038  -3.759432  -4.117386  -5.331863
#           std_sfu     3.874630  5.303453  6.541055   7.817550   8.912016  10.250863
# elevated  mean_sfu   -2.656120 -2.969802 -4.201585  -4.883335  -5.944523  -5.737001
#           std_sfu     4.637809  6.900975  8.823013   9.563252   9.639285   9.826426
# high      mean_sfu  -12.319912 -8.786678 -5.777607  -0.450668   2.979950   3.381168
#           std_sfu     4.984475  3.736044  7.043736  10.935443  13.219880  15.366587

# %%
# Convert df_results into long format
df_results_lf = df_results.melt(id_vars=['variable', 'condition', 'horizon'],
                                value_vars=['mean_sfu', 'std_sfu', 'mean_percent', 'std_percent'],
                                var_name='statistic')

# Filter out the percent statistics
df_results_lf = df_results_lf[df_results_lf['statistic'].str.contains('percent') == False]

# Rename the Statistic 'mean_sfu' to just 'mean' and 'std_sfu' to 'std'
df_results_lf['statistic'] = df_results_lf['statistic'].str.replace('_sfu', '')

df_results_lf.head()
# Out:
#   variable condition  horizon statistic     value
# 0      F10       low        1      mean -0.302316
# 1      F10       low        2      mean -0.583242
# 2      F10       low        3      mean -0.849308
# 3      F10       low        4      mean -0.917582
# 4      F10       low        5      mean -1.263246

# %%
# Compare these results with the results in the paper. The results in the paper
# can be found in the data folder as a csv
df_results_paper = pd.read_csv('../data/paper_results.csv')

# Filter out the rows with Statistics = 'EBM'
df_results_paper = df_results_paper[df_results_paper['statistic'] != 'EBM']

# Rename the values of the column condition to the ones of the sals variable
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Low solar', 'low')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Moderate solar', 'moderate')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Elevated solar', 'elevated')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('High solar', 'high')

df_results_paper.head()
# Out:
#   variable condition statistic   1 Days   2 Days   3 Days   4 Days   5 Days  \
# 0      F10       low      mean  -0.2685  -0.7472  -0.6672  -0.3721  -0.0674
# 1      F10       low       std   3.6985   4.7031   5.5001   6.1683   6.7677
# 3      F10  moderate      mean  -0.8251  -0.8095  -0.9639  -1.1450  -1.1456
# 4      F10  moderate       std  12.0854  14.9853  17.8425  20.2973  21.9353
# 6      F10  elevated      mean   5.7270   7.2425   9.0385  10.3829  11.0017
#
#     6 Days
# 0   0.2428
# 1   7.2050
# 3  -1.1679
# 4  23.3389
# 6  10.9559

# %%
# Convert df_results_paper into long format
df_results_paper_lf = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'],
                                            value_vars=[f'{i} Days' for i in range(1, horizon+1)],
                                            var_name='horizon', value_name='value')

# Convert the value sof the horizon column to int
df_results_paper_lf['horizon'] = df_results_paper_lf['horizon'].str.replace(' Days', '').astype(int)
df_results_paper_lf.head()
# Out:
#   variable condition statistic  horizon    value
# 0      F10       low      mean        1  -0.2685
# 1      F10       low       std        1   3.6985
# 2      F10  moderate      mean        1  -0.8251
# 3      F10  moderate       std        1  12.0854
# 4      F10  elevated      mean        1   5.7270

# %%
# Join the two dataframes (df_results_ours and df_results_paper) on the columns 
# variable, condition and Statistic
df_results_joined = df_results_lf.merge(df_results_paper_lf, how='left', 
                                            on=['variable', 'condition', 'statistic', 'horizon'],
                                            suffixes=('_ours', '_paper'))
len(df_results_lf), len(df_results_paper_lf), len(df_results_joined)
# Out:
# (192, 192, 192)

# %% [markdown]
# ### Visualize predictions

# %%
df_long = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'], 
                      var_name='horizon', value_name='value')

df_long['horizon'] = df_long['horizon'].str.extract('(\d)').astype(int)
    
sfu_stats = df_long.groupby(['variable', 'condition','statistic', 'horizon']).agg(
        values=('value', 'mean')
    ).reset_index()

df_results_paper_formated = sfu_stats[['variable','condition','horizon']].iloc[np.where(sfu_stats['statistic'] == 'mean')]
df_results_paper_formated['std_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] != 'mean')].values
df_results_paper_formated['mean_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] == 'mean')].values
df_results_paper_formated['n_samples'] = np.nan
df_results_paper_formated['mean_sfu'] = np.nan
df_results_paper_formated['std_sfu'] = np.nan

df_results_paper_formated.reset_index()
# Out:
#     index variable condition  horizon  std_percent  mean_percent  n_samples  \
# 0       0      F10  elevated        1      18.3328        5.7270        NaN
# 1       1      F10  elevated        2      22.1021        7.2425        NaN
# 2       2      F10  elevated        3      25.2942        9.0385        NaN
# 3       3      F10  elevated        4      27.0774       10.3829        NaN
# 4       4      F10  elevated        5      27.5279       11.0017        NaN
# ..    ...      ...       ...      ...          ...           ...        ...
# 91    181      Y10  moderate        2      10.1811       -1.3317        NaN
# 92    182      Y10  moderate        3      11.8475       -1.7651        NaN
# 93    183      Y10  moderate        4      13.0170       -2.1734        NaN
# 94    184      Y10  moderate        5      13.8737       -2.5561        NaN
# 95    185      Y10  moderate        6      14.8937       -2.9688        NaN
#
#     mean_sfu  std_sfu
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 91       NaN      NaN
# 92       NaN      NaN
# 93       NaN      NaN
# 94       NaN      NaN
# 95       NaN      NaN
#
# [96 rows x 9 columns]

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'F10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'S10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'M10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'Y10')

# %%
pivoted_df = df_results_joined.pivot_table(index=['variable', 'condition', 'statistic'], 
                            columns='horizon', 
                            values=['value_ours','value_paper'], 
                            aggfunc='first').reset_index()

# To order the columns in the way that we want
condition_order = ['low', 'moderate', 'elevated', 'high']
pivoted_df['condition'] = pd.Categorical(pivoted_df['condition'], categories=condition_order, ordered=True)

# Format columns names
pivoted_df.columns = pd.MultiIndex.from_tuples(
    list(pivoted_df.columns[:3]) + 
    [(value, f'{i} Days Horizon') for value in ['Value Ours', 'Value Benchmark'] for i in range(1,7)]
)

pivoted_df = pivoted_df.sort_values([('variable',''),('condition','')])
pivoted_df.head(1)
# Out:
#   variable condition statistic     Value Ours                                \
#                                1 Days Horizon 2 Days Horizon 3 Days Horizon
# 4      F10       low      mean      -0.302316      -0.583242      -0.849308
#
#                                                Value Benchmark                 \
#   4 Days Horizon 5 Days Horizon 6 Days Horizon  1 Days Horizon 2 Days Horizon
# 4      -0.917582      -1.263246      -1.387918         -0.2685        -0.7472
#
#
#   3 Days Horizon 4 Days Horizon 5 Days Horizon 6 Days Horizon
# 4        -0.6672        -0.3721        -0.0674         0.2428

# %%
def highlight_max(row):
    # Empty color mask
    colors = [''] * len(row)
    columns = ['Value Ours', 'Value Benchmark']
    min_values = []
    
    for i in range(1,7):
        min_values.append(
            min(
                abs(row[('Value Ours', f'{i} Days Horizon')]), 
                abs(row[('Value Benchmark', f'{i} Days Horizon')])
            )
        )
    for i, value in enumerate(row[columns]):
        if np.abs(value) in min_values:
            colors[i+3] = 'background-color: grey'  # The 3 first columns are tags and no data
    return colors

# Compare and highlight # Get max of each element in both dataframes
styled_result = pivoted_df.style.apply(highlight_max, axis=1)

styled_result
# Out:
# <style type="text/css">
# #T_c6cba_row0_col4, #T_c6cba_row0_col9, #T_c6cba_row0_col11, #T_c6cba_row0_col12, #T_c6cba_row0_col13, #T_c6cba_row0_col14, #T_c6cba_row1_col3, #T_c6cba_row1_col4, #T_c6cba_row1_col5, #T_c6cba_row1_col6, #T_c6cba_row1_col7, #T_c6cba_row1_col8, #T_c6cba_row2_col9, #T_c6cba_row2_col10, #T_c6cba_row2_col11, #T_c6cba_row2_col12, #T_c6cba_row2_col13, #T_c6cba_row2_col14, #T_c6cba_row3_col3, #T_c6cba_row3_col4, #T_c6cba_row3_col5, #T_c6cba_row3_col6, #T_c6cba_row3_col7, #T_c6cba_row3_col8, #T_c6cba_row4_col3, #T_c6cba_row4_col4, #T_c6cba_row4_col5, #T_c6cba_row4_col6, #T_c6cba_row4_col7, #T_c6cba_row4_col8, #T_c6cba_row5_col3, #T_c6cba_row5_col4, #T_c6cba_row5_col5, #T_c6cba_row5_col6, #T_c6cba_row5_col7, #T_c6cba_row5_col8, #T_c6cba_row6_col3, #T_c6cba_row6_col4, #T_c6cba_row6_col5, #T_c6cba_row6_col6, #T_c6cba_row6_col7, #T_c6cba_row6_col8, #T_c6cba_row7_col3, #T_c6cba_row7_col4, #T_c6cba_row7_col5, #T_c6cba_row7_col6, #T_c6cba_row7_col7, #T_c6cba_row7_col8, #T_c6cba_row8_col3, #T_c6cba_row8_col4, #T_c6cba_row8_col5, #T_c6cba_row8_col6, #T_c6cba_row8_col7, #T_c6cba_row8_col8, #T_c6cba_row9_col3, #T_c6cba_row9_col4, #T_c6cba_row9_col5, #T_c6cba_row9_col6, #T_c6cba_row9_col7, #T_c6cba_row9_col8, #T_c6cba_row10_col9, #T_c6cba_row10_col10, #T_c6cba_row10_col11, #T_c6cba_row10_col12, #T_c6cba_row10_col13, #T_c6cba_row10_col14, #T_c6cba_row11_col3, #T_c6cba_row11_col4, #T_c6cba_row11_col5, #T_c6cba_row11_col6, #T_c6cba_row11_col7, #T_c6cba_row11_col8, #T_c6cba_row12_col4, #T_c6cba_row12_col5, #T_c6cba_row12_col6, #T_c6cba_row12_col7, #T_c6cba_row12_col8, #T_c6cba_row12_col9, #T_c6cba_row13_col3, #T_c6cba_row13_col4, #T_c6cba_row13_col5, #T_c6cba_row13_col6, #T_c6cba_row13_col7, #T_c6cba_row13_col8, #T_c6cba_row14_col3, #T_c6cba_row14_col4, #T_c6cba_row14_col5, #T_c6cba_row14_col6, #T_c6cba_row14_col7, #T_c6cba_row14_col8, #T_c6cba_row15_col3, #T_c6cba_row15_col4, #T_c6cba_row15_col5, #T_c6cba_row15_col6, #T_c6cba_row15_col7, #T_c6cba_row15_col8, #T_c6cba_row16_col9, #T_c6cba_row16_col10, #T_c6cba_row16_col11, #T_c6cba_row16_col12, #T_c6cba_row16_col13, #T_c6cba_row16_col14, #T_c6cba_row17_col3, #T_c6cba_row17_col4, #T_c6cba_row17_col5, #T_c6cba_row17_col6, #T_c6cba_row17_col7, #T_c6cba_row17_col14, #T_c6cba_row18_col9, #T_c6cba_row18_col10, #T_c6cba_row18_col11, #T_c6cba_row18_col12, #T_c6cba_row18_col13, #T_c6cba_row18_col14, #T_c6cba_row19_col3, #T_c6cba_row19_col4, #T_c6cba_row19_col5, #T_c6cba_row19_col6, #T_c6cba_row19_col7, #T_c6cba_row19_col8, #T_c6cba_row20_col9, #T_c6cba_row20_col10, #T_c6cba_row20_col11, #T_c6cba_row20_col12, #T_c6cba_row20_col13, #T_c6cba_row20_col14, #T_c6cba_row21_col3, #T_c6cba_row21_col4, #T_c6cba_row21_col5, #T_c6cba_row21_col6, #T_c6cba_row21_col7, #T_c6cba_row21_col8, #T_c6cba_row22_col3, #T_c6cba_row22_col4, #T_c6cba_row22_col5, #T_c6cba_row22_col6, #T_c6cba_row22_col7, #T_c6cba_row22_col8, #T_c6cba_row23_col3, #T_c6cba_row23_col4, #T_c6cba_row23_col5, #T_c6cba_row23_col6, #T_c6cba_row23_col7, #T_c6cba_row23_col8, #T_c6cba_row24_col3, #T_c6cba_row24_col10, #T_c6cba_row24_col11, #T_c6cba_row24_col12, #T_c6cba_row24_col13, #T_c6cba_row24_col14, #T_c6cba_row25_col3, #T_c6cba_row25_col4, #T_c6cba_row25_col5, #T_c6cba_row25_col6, #T_c6cba_row25_col7, #T_c6cba_row25_col8, #T_c6cba_row26_col9, #T_c6cba_row26_col10, #T_c6cba_row26_col11, #T_c6cba_row26_col12, #T_c6cba_row26_col13, #T_c6cba_row26_col14, #T_c6cba_row27_col3, #T_c6cba_row27_col4, #T_c6cba_row27_col5, #T_c6cba_row27_col6, #T_c6cba_row27_col7, #T_c6cba_row27_col8, #T_c6cba_row28_col9, #T_c6cba_row28_col10, #T_c6cba_row28_col11, #T_c6cba_row28_col12, #T_c6cba_row28_col13, #T_c6cba_row28_col14, #T_c6cba_row29_col3, #T_c6cba_row29_col4, #T_c6cba_row29_col5, #T_c6cba_row29_col6, #T_c6cba_row29_col7, #T_c6cba_row29_col8, #T_c6cba_row30_col6, #T_c6cba_row30_col7, #T_c6cba_row30_col8, #T_c6cba_row30_col9, #T_c6cba_row30_col10, #T_c6cba_row30_col11, #T_c6cba_row31_col3, #T_c6cba_row31_col4, #T_c6cba_row31_col5, #T_c6cba_row31_col6, #T_c6cba_row31_col13, # ...
#   background-color: grey;
# }
# </style>
# <table id="T_c6cba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6cba_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_c6cba_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_c6cba_level0_col2" class="col_heading level0 col2" >statistic</th>
#       <th id="T_c6cba_level0_col3" class="col_heading level0 col3" colspan="6">Value Ours</th>
#       <th id="T_c6cba_level0_col9" class="col_heading level0 col9" colspan="6">Value Benchmark</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_c6cba_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_c6cba_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_c6cba_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_c6cba_level1_col3" class="col_heading level1 col3" >1 Days Horizon</th>
#       <th id="T_c6cba_level1_col4" class="col_heading level1 col4" >2 Days Horizon</th>
#       <th id="T_c6cba_level1_col5" class="col_heading level1 col5" >3 Days Horizon</th>
#       <th id="T_c6cba_level1_col6" class="col_heading level1 col6" >4 Days Horizon</th>
#       <th id="T_c6cba_level1_col7" class="col_heading level1 col7" >5 Days Horizon</th>
#       <th id="T_c6cba_level1_col8" class="col_heading level1 col8" >6 Days Horizon</th>
#       <th id="T_c6cba_level1_col9" class="col_heading level1 col9" >1 Days Horizon</th>
#       <th id="T_c6cba_level1_col10" class="col_heading level1 col10" >2 Days Horizon</th>
#       <th id="T_c6cba_level1_col11" class="col_heading level1 col11" >3 Days Horizon</th>
#       <th id="T_c6cba_level1_col12" class="col_heading level1 col12" >4 Days Horizon</th>
#       <th id="T_c6cba_level1_col13" class="col_heading level1 col13" >5 Days Horizon</th>
#       <th id="T_c6cba_level1_col14" class="col_heading level1 col14" >6 Days Horizon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6cba_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_c6cba_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_c6cba_row0_col1" class="data row0 col1" >low</td>
#       <td id="T_c6cba_row0_col2" class="data row0 col2" >mean</td>
#       <td id="T_c6cba_row0_col3" class="data row0 col3" >-0.302316</td>
#       <td id="T_c6cba_row0_col4" class="data row0 col4" >-0.583242</td>
#       <td id="T_c6cba_row0_col5" class="data row0 col5" >-0.849308</td>
#       <td id="T_c6cba_row0_col6" class="data row0 col6" >-0.917582</td>
#       <td id="T_c6cba_row0_col7" class="data row0 col7" >-1.263246</td>
#       <td id="T_c6cba_row0_col8" class="data row0 col8" >-1.387918</td>
#       <td id="T_c6cba_row0_col9" class="data row0 col9" >-0.268500</td>
#       <td id="T_c6cba_row0_col10" class="data row0 col10" >-0.747200</td>
#       <td id="T_c6cba_row0_col11" class="data row0 col11" >-0.667200</td>
#       <td id="T_c6cba_row0_col12" class="data row0 col12" >-0.372100</td>
#       <td id="T_c6cba_row0_col13" class="data row0 col13" >-0.067400</td>
#       <td id="T_c6cba_row0_col14" class="data row0 col14" >0.242800</td>
#     </tr>
#     <tr>
#       <th id="T_c6cba_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c6cba_row1_col0" class="data row1 col0" >F10</td>
#       <td id="T_c6cba_row1_col1" class="data row1 col1" >low</td>
#       <td id="T_c6cba_row1_col2" class="data row1 col2" >std</td>
#       <td id="T_c6cba_row1_col3" class="data row1 col3" >1.545831</td>
#       <td id="T_c6cba_row1_col4" class="data row1 col4" >2.005722</td>
#       <td id="T_c6cba_row1_col5" class="data row1 col5" >2.444186</td>
#       <td id="T_c6cba_row1_col6" class="data row1 col6" >2.878991</td>
#       <td id="T_c6cba_row1_col7" class="data row1 col7" >3.406800</td>
#       <td id="T_c6cba_row1_col8" class="data row1 col8" >3.805427</td>
#       <td id="T_c6cba_row1_col9" class="data row1 col9" >3.698500</td>
#       <td id="T_c6cba_row1_col10" class="data row1 col10" >4.70

# %%
create_latex_comparison_tables(df_results_joined, data_columns_fcst, horizon)
# Out:
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable F10}
# \label{tab:comparison_F10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & -0.30231586 ± \textbf{1.5458306} & \textbf{-0.2685} ± 3.6985 \\
# low & 2 & \textbf{-0.5832418} ± \textbf{2.005722} & -0.7472 ± 4.7031 \\
# low & 3 & -0.84930784 ± \textbf{2.4441862} & \textbf{-0.6672} ± 5.5001 \\
# low & 4 & -0.91758186 ± \textbf{2.878991} & \textbf{-0.3721} ± 6.1683 \\
# low & 5 & -1.2632464 ± \textbf{3.4067998} & \textbf{-0.0674} ± 6.7677 \\
# low & 6 & -1.3879179 ± \textbf{3.805427} & \textbf{0.2428} ± 7.205 \\
# moderate & 1 & -1.9645493 ± \textbf{3.9379232} & \textbf{-0.8251} ± 12.0854 \\
# moderate & 2 & -2.6855822 ± \textbf{5.418038} & \textbf{-0.8095} ± 14.9853 \\
# moderate & 3 & -2.8648553 ± \textbf{6.6251497} & \textbf{-0.9639} ± 17.8425 \\
# moderate & 4 & -3.6452951 ± \textbf{7.953461} & \textbf{-1.145} ± 20.2973 \\
# moderate & 5 & -3.9564571 ± \textbf{8.996822} & \textbf{-1.1456} ± 21.9353 \\
# moderate & 6 & -5.111341 ± \textbf{10.247547} & \textbf{-1.1679} ± 23.3389 \\
# elevated & 1 & \textbf{-5.073747} ± \textbf{4.965025} & 5.727 ± 18.3328 \\
# elevated & 2 & \textbf{-6.6802926} ± \textbf{7.3934536} & 7.2425 ± 22.1021 \\
# elevated & 3 & \textbf{-8.271734} ± \textbf{9.7246275} & 9.0385 ± 25.2942 \\
# elevated & 4 & \textbf{-9.30709} ± \textbf{11.358914} & 10.3829 ± 27.0774 \\
# elevated & 5 & \textbf{-10.227098} ± \textbf{12.064628} & 11.0017 ± 27.5279 \\
# elevated & 6 & \textbf{-9.636679} ± \textbf{12.77586} & 10.9559 ± 26.9074 \\
# high & 1 & \textbf{-3.9949434} ± \textbf{4.771769} & 15.7448 ± 20.2227 \\
# high & 2 & \textbf{-5.577252} ± \textbf{6.1402225} & 19.5749 ± 24.7236 \\
# high & 3 & \textbf{-6.8727965} ± \textbf{6.3609242} & 24.2444 ± 27.6092 \\
# high & 4 & \textbf{-7.453322} ± \textbf{6.9474783} & 26.6674 ± 30.8869 \\
# high & 5 & \textbf{-7.080386} ± \textbf{8.527883} & 26.023 ± 33.9069 \\
# high & 6 & \textbf{-5.439536} ± \textbf{9.40399} & 23.9778 ± 35.9795 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable S10}
# \label{tab:comparison_S10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & -0.8509943 ± \textbf{2.6082964} & \textbf{0.2206} ± 5.8378 \\
# low & 2 & -1.3480932 ± \textbf{5.197949} & \textbf{-0.0343} ± 5.7474 \\
# low & 3 & -1.5500845 ± \textbf{4.394403} & \textbf{-0.1044} ± 5.8682 \\
# low & 4 & -1.7499993 ± \textbf{5.0899525} & \textbf{-0.0985} ± 6.0709 \\
# low & 5 & -2.1230638 ± \textbf{5.706548} & \textbf{-0.066} ± 6.1153 \\
# low & 6 & -2.2809396 ± 7.440813 & \textbf{-0.0501} ± \textbf{6.0475} \\
# moderate & 1 & -2.1244938 ± \textbf{3.9280198} & \textbf{0.1111} ± 10.0715 \\
# moderate & 2 & -2.8740752 ± \textbf{5.3746357} & \textbf{0.219} ± 11.7059 \\
# moderate & 3 & -3.1764963 ± \textbf{6.629379} & \textbf{0.2974} ± 13.5434 \\
# moderate & 4 & -3.7788165 ± \textbf{7.843639} & \textbf{0.3426} ± 14.9844 \\
# moderate & 5 & -4.192246 ± \textbf{8.9786} & \textbf{0.2977} ± 16.1132 \\
# moderate & 6 & -5.4189963 ± \textbf{10.38938} & \textbf{0.1862} ± 17.1467 \\
# elevated & 1 & -2.4975994 ± \textbf{4.224321} & \textbf{-1.1311} ± 16.5592 \\
# elevated & 2 & -3.1956308 ± \textbf{6.1648445} & \textbf{-1.7989} ± 19.205 \\
# elevated & 3 & -4.302513 ± \textbf{7.9082894} & \textbf{-2.2361} ± 21.9271 \\
# elevated & 4 & -5.094389 ± \textbf{9.539131} & \textbf{-2.691} ± 24.1118 \\
# elevated & 5 & -5.8782845 ± \textbf{10.176993} & \textbf{-2.8148} ± 25.8017 \\
# elevated & 6 & -6.20041 ± \textbf{10.651926} & \textbf{-2.7593} ± 27.2658 \\
# high & 1 & \textbf{-3.2396967} ± \textbf{3.8729017} & 16.204 ± 35.3267 \\
# high & 2 & \textbf{-4.0608196} ± \textbf{5.952044} & 23.1628 ± 39.6577 \\
# high & 3 & \textbf{-3.6405103} ± \textbf{9.236991} & 28.3943 ± 39.6471 \\
# high & 4 & \textbf{-2.5632436} ± \textbf{11.282063} & 31.4085 ± 38.7875 \\
# high & 5 & \textbf{-2.5072153} ± \textbf{12.799155} & 31.6158 ± 38.5307 \\
# high & 6 & \textbf{-1.9908376} ± \textbf{12.595369} & 30.1409 ± 38.6613 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable M10}
# \label{tab:comparison_M10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.45410562} ± \textbf{1.8387057} & -0.9582 ± 5.1317 \\
# low & 2 & \textbf{-0.70349973} ± \textbf{2.5377908} & -1.1063 ± 5.6375 \\
# low & 3 & \textbf{-0.98959947} ± \textbf{3.2688448} & -1.2667 ± 6.225 \\
# low & 4 & \textbf{-1.0797426} ± \textbf{3.8750913} & -1.4203 ± 6.4693 \\
# low & 5 & \textbf{-1.3576453} ± \textbf{4.2714887} & -1.5303 ± 6.8538 \\
# low & 6 & \textbf{-1.4272331} ± \textbf{4.5314903} & -1.6171 ± 7.2024 \\
# moderate & 1 & -1.9885483 ± \textbf{3.8982446} & \textbf{-0.5138} ± 8.9027 \\
# moderate & 2 & -2.7826931 ± \textbf{5.351664} & \textbf{-0.7424} ± 11.2745 \\
# moderate & 3 & -3.0170577 ± \textbf{6.5914726} & \textbf{-0.9976} ± 13.4329 \\
# moderate & 4 & -3.9180777 ± \textbf{7.9113784} & \textbf{-1.1619} ± 15.1962 \\
# moderate & 5 & -4.3077445 ± \textbf{9.027927} & \textbf{-1.237} ± 16.4221 \\
# moderate & 6 & -5.478997 ± \textbf{10.366497} & \textbf{-1.3348} ± 17.4041 \\
# elevated & 1 & -4.3503337 ± \textbf{5.1595235} & \textbf{3.7282} ± 10.4528 \\
# elevated & 2 & \textbf{-4.746852} ± \textbf{7.7239475} & 5.6301 ± 13.4784 \\
# elevated & 3 & \textbf{-4.937865} ± \textbf{10.018027} & 7.3375 ± 16.1156 \\
# elevated & 4 & \textbf{-4.761235} ± \textbf{11.088537} & 8.5258 ± 17.9805 \\
# elevated & 5 & \textbf{-5.052602} ± \textbf{11.477722} & 9.0192 ± 18.9175 \\
# elevated & 6 & \textbf{-3.9852664} ± \textbf{11.517286} & 8.9334 ± 19.077 \\
# high & 1 & \textbf{-2.9038208} ± \textbf{3.5918572} & 4.6517 ± 9.2079 \\
# high & 2 & \textbf{-3.4932866} ± \textbf{4.7148304} & 6.3966 ± 12.7892 \\
# high & 3 & \textbf{-3.6406147} ± \textbf{5.929944} & 8.8328 ± 16.4932 \\
# high & 4 & \textbf{-2.7075236} ± \textbf{6.70416} & 10.95 ± 19.2241 \\
# high & 5 & \textbf{-2.1430995} ± \textbf{7.021248} & 12.3435 ± 20.913 \\
# high & 6 & \textbf{-0.70862657} ± \textbf{7.9619613} & 12.9784 ± 21.582 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable Y10}
# \label{tab:comparison_Y10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.32224682} ± \textbf{1.5367594} & -0.427 ± 4.5093 \\
# low & 2 & -0.5220428 ± \textbf{1.9374131} & \textbf{-0.2282} ± 4.9373 \\
# low & 3 & -0.7747431 ± \textbf{2.3008246} & \textbf{-0.0684} ± 5.4416 \\
# low & 4 & -0.7942611 ± \textbf{2.6211488} & \textbf{0.0902} ± 5.9977 \\
# low & 5 & -1.0618348 ± \textbf{3.0072675} & \textbf{0.2697} ± 6.4255 \\
# low & 6 & -1.0832943 ± \textbf{3.0639725} & \textbf{0.465} ± 6.816 \\
# moderate & 1 & -2.0624208 ± \textbf{3.8746297} & \textbf{-0.8277} ± 8.5137 \\
# moderate & 2 & -2.8068438 ± \textbf{5.3034534} & \textbf{-1.3317} ± 10.1811 \\
# moderate & 3 & -3.077038 ± \textbf{6.5410547} & \textbf{-1.7651} ± 11.8475 \\
# moderate & 4 & -3.7594323 ± \textbf{7.81755} & \textbf{-2.1734} ± 13.017 \\
# moderate & 5 & -4.117386 ± \textbf{8.912016} & \textbf{-2.5561} ± 13.8737 \\
# moderate & 6 & -5.3318634 ± \textbf{10.250863} & \textbf{-2.9688} ± 14.8937 \\
# elevated & 1 & -2.6561198 ± \textbf{4.637809} & \textbf{2.1089} ± 7.7173 \\
# elevated & 2 & -2.9698021 ± \textbf{6.900975} & \textbf{1.7243} ± 9.3066 \\
# elevated & 3 & -4.201585 ± \textbf{8.823013} & \textbf{2.0679} ± 10.6086 \\
# elevated & 4 & -4.883335 ± \textbf{9.563252} & \textbf{2.5656} ± 11.4955 \\
# elevated & 5 & -5.944523 ± \textbf{9.639285} & \textbf{2.7714} ± 11.8996 \\
# elevated & 6 & -5.7370014 ± \textbf{9.826426} & \textbf{2.8423} ± 11.9965 \\
# high & 1 & -12.319912 ± \textbf{4.9844747} & \textbf{5.2729} ± 8.5806 \\
# high & 2 & -8.786678 ± \textbf{3.7360437} & \textbf{4.2075} ± 10.8097 \\
# high & 3 & -5.777607 ± \textbf{7.043736} & \textbf{4.5855} ± 11.5436 \\
# high & 4 & \textbf{-0.45066833} ± \textbf{10.935443} & 5.2131 ± 11.3048 \\
# high & 5 & \textbf{2.97995} ± 13.21988 & 5.6561 ± \textbf{11.019} \\
# high & 6 & \textbf{3.3811684} ± 15.366587 & 6.014 ± \textbf{10.4416} \\
# \bottomrule
# \end{tabular}
# \end{table}
