# %% [markdown]
# # Evaluation of SOLFSMY
#
# > With respect to the benchmark by Licata et al.

# %%
# Imports
import sys
sys.path.append('..')
from swdf.benchmark import *
from tsai.basics import *
from sklearn.metrics import mean_squared_error, mean_absolute_error
from swdf.utils import *
import wandb
from swdf.losses import *
wandb_api = wandb.Api()
# Out:
# /usr/local/pip-global/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# Constants
# ARTIFACT_DOWNLOAD_PATH = Path(os.environ["WANDB_DIR"])/"wandb/artifacts/solfsmy_eval_tmp"

# %%
# Config
config = yaml2dict('config/solfsmy.yaml')
config = config.eval

config_base = yaml2dict('config/base.yaml')

config, config_base
# Out:
# ({'dst_data_path': '../data/DST_IAGA2002.txt',
#   'learner_artifact': None,
#   'round_preds': True,
#   'solfsmy_data_path': '../data/SOLFSMY.TXT'},
#  {'arch_name': 'PatchTST',
#   'arch_config_file': 'config/patchtst.yaml',
#   'bs': 1024,
#   'horizon': 6,
#   'init_weights': False,
#   'lookback': 36,
#   'lr_max': None,
#   'n_epoch': 5,
#   'partial_n': 0.1,
#   'seed': 42,
#   'test_start_datetime': '2012-10-01 12:00:00',
#   'test_end_datetime': '2018-12-31 12:00:00',
#   'wandb': {'enabled': False,
#    'log_learner': True,
#    'mode': 'offline',
#    'group': None,
#    'project': 'swdf'}})

# %%
learn_wMAE = load_learner_all("tmp", model_fname = 'model_wMAE', learner_fname="learner_wMAE", 
                         verbose=True, 
                         device=default_device())

learn_wMSE = load_learner_all("tmp", model_fname = 'model_wMSE', learner_fname="learner_wMSE", 
                         verbose=True, 
                         device=default_device())
# Out:
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth', 'dls_4.pth', 'dls_5.pth', 'dls_6.pth']'
# model_fname   = 'model_wMAE.pth'
# learner_fname = 'learner_wMAE.pkl'
# Learner loaded:
# path          = 'tmp'
# dls_fname     = '['dls_0.pth', 'dls_1.pth', 'dls_2.pth', 'dls_3.pth', 'dls_4.pth', 'dls_5.pth', 'dls_6.pth']'
# model_fname   = 'model_wMSE.pth'
# learner_fname = 'learner_wMSE.pkl'

# %%
y_test_preds_wMAE, y_test = learn_wMAE.get_preds(ds_idx = 2, with_targs=True)
y_test_preds_wMSE, _ = learn_wMSE.get_preds(ds_idx = 2, with_targs=True) 

y_test_preds = (y_test_preds_wMAE + y_test_preds_wMSE) / 2

y_test_preds = to_np(y_test_preds)
y_test = to_np(y_test)
print(f"y_test_preds.shape: {y_test_preds.shape}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# y_test_preds.shape: (2242, 4, 6)

# %%
horizon = y_test.shape[-1]
data_columns_fcst = ['F10', 'S10', 'M10', 'Y10']

# %% [markdown]
# The evaluation is done for each variable separately, for each solar activity
# level (low, moderate, elevated and high), as in the paper by Licata et al. (2020)
# Therefore, the test set has to be split into 4 different sets, one for each solar activity level. The thresholds for each solar activity level are the same as in the paper by Licata et al. (2020)
#
# The thresholds are:
# - F10: 75, 150, 190
# - S10: 65, 150, 215
# - M10: 72, 144, 167
# - Y10: 81, 148, 165

# %%
#|export

def get_idxs_per_solar_activity_level(data, thresholds):
    # function that splits the data of a variable into 4 different sets, 
    # one for each solar activity level. The data comes as a numpy array with 
    # shape (samples, steps), and the split is done along the samples axis. 
    # The decision is made based on the first column of each sample. The function 
    # returns a list of 4 numpy arrays, one for each solar activity level. 
    # But it does not return the values, it returns the indices of the
    # samples that belong to each solar activity level.
    idxs_per_solar_activity_level = []
    for i in range(len(thresholds) + 1):
        if i == 0:
            idxs = np.where(data[:, 0] <= thresholds[i])[0]
        elif i == len(thresholds):
            idxs = np.where(data[:, 0] > thresholds[i-1])[0]
        else:
            idxs = np.where((data[:, 0] > thresholds[i-1]) & (data[:, 0] <= thresholds[i]))[0]
        idxs_per_solar_activity_level.append(idxs)
    return idxs_per_solar_activity_level

# %%
# Call the function for each variable, using y_test
thresholds = {'F10': [75, 150, 190], 
              'S10': [65, 150, 215], 
              'M10': [72, 144, 167], 
              'Y10': [81, 148, 165]}

y_test_split_idxs = {}
for i, var in enumerate(data_columns_fcst):
    y_test_split_idxs[var] = get_idxs_per_solar_activity_level(y_test[:, i, :], 
                                                               thresholds[var])
# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(494,), (1465,), (283,), (0,)]
# M10: [(535,), (1442,), (235,), (30,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
df_SET = pd.read_pickle('preprocessed_data/dataframes/set_solfsmy.pkl')

_, y_test_SET = SlidingWindow(
            window_len=config_base.lookback,
            horizon=config_base.horizon, 
            stride=1, 
            get_x=['S10'], 
            get_y=['S10']
        )(df_SET)

y_test_split_idxs['S10'] = get_idxs_per_solar_activity_level(y_test_SET, thresholds['S10'])

# Check the shape of each variable
for var in data_columns_fcst:
    print(f"{var}: {[y_test_split_idxs[var][i].shape for i in range(4)]}")
# Out:
# F10: [(591,), (1423,), (205,), (23,)]
# S10: [(520,), (1421,), (267,), (33,)]
# M10: [(535,), (1442,), (235,), (30,)]
# Y10: [(487,), (1654,), (97,), (4,)]

# %%
# Now split y_test and y_test_preds with the idxs we got, using numpy.take
y_test_split = {}
y_test_preds_split = {}
for var in data_columns_fcst:
    y_test_split[var] = [y_test[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]
    y_test_preds_split[var] = [y_test_preds[:, i, :].take(y_test_split_idxs[var][i], axis=0) for i in range(4)]

# Check the shape of each variable in y_test_split
for var in data_columns_fcst:
    print(f"y_test-{var}: {[y_test_split[var][i].shape for i in range(4)]}")
    print(f"y_test_preds-{var}: {[y_test_preds_split[var][i].shape for i in range(4)]}")
# Out:
# y_test-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test_preds-F10: [(591, 6), (1423, 6), (205, 6), (23, 6)]
# y_test-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test_preds-S10: [(520, 6), (1421, 6), (267, 6), (33, 6)]
# y_test-M10: [(535, 6), (1442, 6), (235, 6), (30, 6)]
# y_test_preds-M10: [(535, 6), (1442, 6), (235, 6), (30, 6)]
# y_test-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]
# y_test_preds-Y10: [(487, 6), (1654, 6), (97, 6), (4, 6)]

# %%
# Create a table (dataframe) with the mean forecast error for each variable (F10, S10, M10, Y10), 
# each solar activity level and each horizon (1..horizon)
data = []
sals = ['low', 'moderate', 'elevated', 'high']
for var_idx, var in enumerate(data_columns_fcst):
    for sal_idx,sal in enumerate(sals):
        for h in range(1, horizon+1):
            fe_sfu = forecast_error(y_test_split[var][sal_idx], 
                                y_test_preds_split[var][sal_idx], h)
            fe_percent = percent_forecast_error(y_test_split[var][sal_idx],
                                            y_test_preds_split[var][sal_idx], h)
            n_samples = y_test_split[var][sal_idx].shape[0]
            data.append([var, sal, h, np.mean(fe_sfu), np.std(fe_sfu), 
                        np.mean(fe_percent), np.std(fe_percent), n_samples])
df_results = pd.DataFrame(data, columns=['variable', 'condition', 'horizon', 
                                         'mean_sfu', 'std_sfu', 'mean_percent', 
                                         'std_percent', 'n_samples'])
df_results.head(10)
# Out:
#   variable condition  horizon  mean_sfu   std_sfu  mean_percent  std_percent  \
# 0      F10       low        1 -0.071236  1.696314     -0.098279     2.364529
# 1      F10       low        2  0.259902  2.168204      0.389877     3.004626
# 2      F10       low        3  0.093957  2.773656      0.176220     3.789798
# 3      F10       low        4  0.332901  3.255150      0.551312     4.412354
# 4      F10       low        5  0.209407  3.777593      0.424267     5.007872
# 5      F10       low        6 -0.016804  4.021286      0.147710     5.181148
# 6      F10  moderate        1 -0.426572  3.757004     -0.353345     3.145612
# 7      F10  moderate        2  0.028090  5.244784      0.095978     4.349980
# 8      F10  moderate        3  0.033294  6.400348      0.221772     5.377307
# 9      F10  moderate        4 -0.473253  7.513208     -0.107378     6.225582
#
#    n_samples
# 0        591
# 1        591
# 2        591
# 3        591
# 4        591
# 5        591
# 6       1423
# 7       1423
# 8       1423
# 9       1423

# %%
# Divide the table into one dataframe for each variable, and print it in a way
# that has the same format as the table in the paper, that is:
# Columns: | Condition | Statistics | 1 Day | 2 Days | 3 Days | ... | {{horizon}} Days,
# where condition is the variable and the solar activity level, and statistics 
# is the mean (column mean_fe) and the standard deviation (std_fe) of the forecast error.
for i, var in enumerate(data_columns_fcst):
    df_var = df_results[df_results['variable'] == var]

    df_var = df_var.melt(id_vars=['condition', 'horizon'], 
                         value_vars=['mean_sfu', 'std_sfu'], 
                         var_name='Statistic')
    # Sort the values of the column condition so that the order is 
    # low, moderate, elevated, high
    df_var['condition'] = pd.Categorical(df_var['condition'], 
                                      categories=['low', 'moderate', 'elevated', 'high'], 
                                      ordered=True)
    df_var = df_var.pivot_table(index=['condition', 'Statistic'], 
                          columns='horizon', 
                          values='value')
    # pretty print, and separate with a blank line
    print(f'Distribution Statistics {var} Error Distribution \n{df_var.to_string()}\n')
# Out:
# Distribution Statistics F10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.071236  0.259902  0.093957   0.332901   0.209407  -0.016804
#           std_sfu    1.696314  2.168204  2.773656   3.255150   3.777593   4.021286
# moderate  mean_sfu  -0.426572  0.028090  0.033294  -0.473253  -0.203738  -0.475232
#           std_sfu    3.757004  5.244784  6.400348   7.513208   8.858162  10.058877
# elevated  mean_sfu  -3.264493 -3.672162 -3.875309  -3.099677  -2.622988  -1.217701
#           std_sfu    5.049813  7.633696  9.438831  11.299518  12.187860  13.208594
# high      mean_sfu  -3.022292 -2.929564 -3.674866  -5.883204  -4.449245  -1.514652
#           std_sfu    4.474904  5.360960  5.417838   6.599428   8.555874   9.751790
#
# Distribution Statistics S10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.189986 -0.185653 -0.349827  -0.091642   0.021045  -0.512045
#           std_sfu    2.860843  5.282431  4.428138   5.312958   5.950978   7.514809
# moderate  mean_sfu  -0.370732  0.008241 -0.129053  -0.508584  -0.113193  -0.144117
#           std_sfu    3.676235  5.083477  6.379656   7.425281   8.693423   9.846501
# elevated  mean_sfu  -0.698680 -0.742545 -0.571754  -0.877645   0.283860   0.544549
#           std_sfu    4.095662  5.993514  7.430784   9.660759  10.082962  10.984032
# high      mean_sfu  -1.244241 -1.201453  0.033226  -0.304637   1.634094   3.182408
#           std_sfu    3.710903  5.973325  9.711154  11.299147  11.684377  11.077234
#
# Distribution Statistics M10 Error Distribution
# horizon                     1         2         3          4          5          6
# condition Statistic
# low       mean_sfu  -0.188373  0.084064 -0.133642   0.181249   0.156284  -0.085331
#           std_sfu    2.167279  2.843262  3.820265   4.357989   4.926046   5.080371
# moderate  mean_sfu  -0.510711 -0.173787 -0.114240  -0.777791  -0.604304  -1.013149
#           std_sfu    3.697446  5.073934  6.308383   7.398797   8.662107   9.759053
# elevated  mean_sfu  -2.387660 -1.602494 -0.798142   1.080047   2.304469   4.712436
#           std_sfu    4.901175  7.369403  8.860009  10.187113  10.577886  10.910546
# high      mean_sfu  -1.054716 -0.453242 -0.289321  -1.128407   0.762724   3.186474
#           std_sfu    3.122735  4.204766  5.437541   6.093189   7.243398   7.814160
#
# Distribution Statistics Y10 Error Distribution
# horizon                      1         2          3          4          5          6
# condition Statistic
# low       mean_sfu   -0.074776  0.302995   0.164151   0.442795   0.427397   0.214377
#           std_sfu     1.874006  2.381964   2.699992   3.112237   3.545460   3.392639
# moderate  mean_sfu   -0.421677 -0.014543  -0.070967  -0.521833  -0.188526  -0.292336
#           std_sfu     3.664670  5.076239   6.242871   7.360046   8.650176   9.801798
# elevated  mean_sfu   -1.154572 -0.574635  -0.573454   0.218457   1.155177   3.091263
#           std_sfu     4.244579  6.450173   8.027054   9.517385   9.851047  10.670898
# high      mean_sfu  -11.053905 -5.515690  -1.694317   1.363903   5.823387   8.320732
#           std_sfu     6.584596  4.897326  10.022500  11.905317  11.255660  13.580637

# %%
# Convert df_results into long format
df_results_lf = df_results.melt(id_vars=['variable', 'condition', 'horizon'],
                                value_vars=['mean_sfu', 'std_sfu', 'mean_percent', 'std_percent'],
                                var_name='statistic')

# Filter out the percent statistics
df_results_lf = df_results_lf[df_results_lf['statistic'].str.contains('percent') == False]

# Rename the Statistic 'mean_sfu' to just 'mean' and 'std_sfu' to 'std'
df_results_lf['statistic'] = df_results_lf['statistic'].str.replace('_sfu', '')

df_results_lf.head()
# Out:
#   variable condition  horizon statistic     value
# 0      F10       low        1      mean -0.071236
# 1      F10       low        2      mean  0.259902
# 2      F10       low        3      mean  0.093957
# 3      F10       low        4      mean  0.332901
# 4      F10       low        5      mean  0.209407

# %%
# Compare these results with the results in the paper. The results in the paper
# can be found in the data folder as a csv
df_results_paper = pd.read_csv('../data/paper_results.csv')

# Filter out the rows with Statistics = 'EBM'
df_results_paper = df_results_paper[df_results_paper['statistic'] != 'EBM']

# Rename the values of the column condition to the ones of the sals variable
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Low solar', 'low')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Moderate solar', 'moderate')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('Elevated solar', 'elevated')
df_results_paper['condition'] = df_results_paper['condition'].str.replace('High solar', 'high')

df_results_paper.head()
# Out:
#   variable condition statistic   1 Days   2 Days   3 Days   4 Days   5 Days  \
# 0      F10       low      mean  -0.2685  -0.7472  -0.6672  -0.3721  -0.0674
# 1      F10       low       std   3.6985   4.7031   5.5001   6.1683   6.7677
# 3      F10  moderate      mean  -0.8251  -0.8095  -0.9639  -1.1450  -1.1456
# 4      F10  moderate       std  12.0854  14.9853  17.8425  20.2973  21.9353
# 6      F10  elevated      mean   5.7270   7.2425   9.0385  10.3829  11.0017
#
#     6 Days
# 0   0.2428
# 1   7.2050
# 3  -1.1679
# 4  23.3389
# 6  10.9559

# %%
# Convert df_results_paper into long format
df_results_paper_lf = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'],
                                            value_vars=[f'{i} Days' for i in range(1, horizon+1)],
                                            var_name='horizon', value_name='value')

# Convert the value sof the horizon column to int
df_results_paper_lf['horizon'] = df_results_paper_lf['horizon'].str.replace(' Days', '').astype(int)
df_results_paper_lf.head()
# Out:
#   variable condition statistic  horizon    value
# 0      F10       low      mean        1  -0.2685
# 1      F10       low       std        1   3.6985
# 2      F10  moderate      mean        1  -0.8251
# 3      F10  moderate       std        1  12.0854
# 4      F10  elevated      mean        1   5.7270

# %%
# Join the two dataframes (df_results_ours and df_results_paper) on the columns 
# variable, condition and Statistic
df_results_joined = df_results_lf.merge(df_results_paper_lf, how='left', 
                                            on=['variable', 'condition', 'statistic', 'horizon'],
                                            suffixes=('_ours', '_paper'))
len(df_results_lf), len(df_results_paper_lf), len(df_results_joined)
# Out:
# (192, 192, 192)

# %% [markdown]
# ### Visualize predictions

# %%
df_long = df_results_paper.melt(id_vars=['variable', 'condition', 'statistic'], 
                      var_name='horizon', value_name='value')

df_long['horizon'] = df_long['horizon'].str.extract('(\d)').astype(int)
    
sfu_stats = df_long.groupby(['variable', 'condition','statistic', 'horizon']).agg(
        values=('value', 'mean')
    ).reset_index()

df_results_paper_formated = sfu_stats[['variable','condition','horizon']].iloc[np.where(sfu_stats['statistic'] == 'mean')]
df_results_paper_formated['std_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] != 'mean')].values
df_results_paper_formated['mean_percent'] = sfu_stats['values'].iloc[np.where(sfu_stats['statistic'] == 'mean')].values
df_results_paper_formated['n_samples'] = np.nan
df_results_paper_formated['mean_sfu'] = np.nan
df_results_paper_formated['std_sfu'] = np.nan

df_results_paper_formated.reset_index()
# Out:
#     index variable condition  horizon  std_percent  mean_percent  n_samples  \
# 0       0      F10  elevated        1      18.3328        5.7270        NaN
# 1       1      F10  elevated        2      22.1021        7.2425        NaN
# 2       2      F10  elevated        3      25.2942        9.0385        NaN
# 3       3      F10  elevated        4      27.0774       10.3829        NaN
# 4       4      F10  elevated        5      27.5279       11.0017        NaN
# ..    ...      ...       ...      ...          ...           ...        ...
# 91    181      Y10  moderate        2      10.1811       -1.3317        NaN
# 92    182      Y10  moderate        3      11.8475       -1.7651        NaN
# 93    183      Y10  moderate        4      13.0170       -2.1734        NaN
# 94    184      Y10  moderate        5      13.8737       -2.5561        NaN
# 95    185      Y10  moderate        6      14.8937       -2.9688        NaN
#
#     mean_sfu  std_sfu
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 91       NaN      NaN
# 92       NaN      NaN
# 93       NaN      NaN
# 94       NaN      NaN
# 95       NaN      NaN
#
# [96 rows x 9 columns]

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'F10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'S10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'M10')

# %%
plot_solar_algorithm_performance_comparison(df_results, df_results_paper_formated, 'Y10')

# %%
pivoted_df = df_results_joined.pivot_table(index=['variable', 'condition', 'statistic'], 
                            columns='horizon', 
                            values=['value_ours','value_paper'], 
                            aggfunc='first').reset_index()

# To order the columns in the way that we want
condition_order = ['low', 'moderate', 'elevated', 'high']
pivoted_df['condition'] = pd.Categorical(pivoted_df['condition'], categories=condition_order, ordered=True)

# Format columns names
pivoted_df.columns = pd.MultiIndex.from_tuples(
    list(pivoted_df.columns[:3]) + 
    [(value, f'{i} Days Horizon') for value in ['Value Ours', 'Value Benchmark'] for i in range(1,7)]
)

pivoted_df = pivoted_df.sort_values([('variable',''),('condition','')])
pivoted_df.head(1)
# Out:
#   variable condition statistic     Value Ours                                \
#                                1 Days Horizon 2 Days Horizon 3 Days Horizon
# 4      F10       low      mean      -0.071236       0.259902       0.093957
#
#                                                Value Benchmark                 \
#   4 Days Horizon 5 Days Horizon 6 Days Horizon  1 Days Horizon 2 Days Horizon
# 4       0.332901       0.209407      -0.016804         -0.2685        -0.7472
#
#
#   3 Days Horizon 4 Days Horizon 5 Days Horizon 6 Days Horizon
# 4        -0.6672        -0.3721        -0.0674         0.2428

# %%
def highlight_max(row):
    # Empty color mask
    colors = [''] * len(row)
    columns = ['Value Ours', 'Value Benchmark']
    min_values = []
    
    for i in range(1,7):
        min_values.append(
            min(
                abs(row[('Value Ours', f'{i} Days Horizon')]), 
                abs(row[('Value Benchmark', f'{i} Days Horizon')])
            )
        )
    for i, value in enumerate(row[columns]):
        if np.abs(value) in min_values:
            colors[i+3] = 'background-color: grey'  # The 3 first columns are tags and no data
    return colors

# Compare and highlight # Get max of each element in both dataframes
styled_result = pivoted_df.style.apply(highlight_max, axis=1)

styled_result
# Out:
# <style type="text/css">
# #T_3a504_row0_col3, #T_3a504_row0_col4, #T_3a504_row0_col5, #T_3a504_row0_col6, #T_3a504_row0_col8, #T_3a504_row0_col13, #T_3a504_row1_col3, #T_3a504_row1_col4, #T_3a504_row1_col5, #T_3a504_row1_col6, #T_3a504_row1_col7, #T_3a504_row1_col8, #T_3a504_row2_col3, #T_3a504_row2_col4, #T_3a504_row2_col5, #T_3a504_row2_col6, #T_3a504_row2_col7, #T_3a504_row2_col8, #T_3a504_row3_col3, #T_3a504_row3_col4, #T_3a504_row3_col5, #T_3a504_row3_col6, #T_3a504_row3_col7, #T_3a504_row3_col8, #T_3a504_row4_col3, #T_3a504_row4_col4, #T_3a504_row4_col5, #T_3a504_row4_col6, #T_3a504_row4_col7, #T_3a504_row4_col8, #T_3a504_row5_col3, #T_3a504_row5_col4, #T_3a504_row5_col5, #T_3a504_row5_col6, #T_3a504_row5_col7, #T_3a504_row5_col8, #T_3a504_row6_col3, #T_3a504_row6_col4, #T_3a504_row6_col5, #T_3a504_row6_col6, #T_3a504_row6_col7, #T_3a504_row6_col8, #T_3a504_row7_col3, #T_3a504_row7_col4, #T_3a504_row7_col5, #T_3a504_row7_col6, #T_3a504_row7_col7, #T_3a504_row7_col8, #T_3a504_row8_col3, #T_3a504_row8_col4, #T_3a504_row8_col5, #T_3a504_row8_col6, #T_3a504_row8_col7, #T_3a504_row8_col8, #T_3a504_row9_col3, #T_3a504_row9_col4, #T_3a504_row9_col5, #T_3a504_row9_col6, #T_3a504_row9_col7, #T_3a504_row9_col8, #T_3a504_row10_col3, #T_3a504_row10_col4, #T_3a504_row10_col5, #T_3a504_row10_col6, #T_3a504_row10_col7, #T_3a504_row10_col8, #T_3a504_row11_col3, #T_3a504_row11_col4, #T_3a504_row11_col5, #T_3a504_row11_col6, #T_3a504_row11_col7, #T_3a504_row11_col8, #T_3a504_row12_col3, #T_3a504_row12_col4, #T_3a504_row12_col5, #T_3a504_row12_col6, #T_3a504_row12_col7, #T_3a504_row12_col8, #T_3a504_row13_col3, #T_3a504_row13_col4, #T_3a504_row13_col5, #T_3a504_row13_col6, #T_3a504_row13_col7, #T_3a504_row13_col8, #T_3a504_row14_col3, #T_3a504_row14_col4, #T_3a504_row14_col5, #T_3a504_row14_col6, #T_3a504_row14_col7, #T_3a504_row14_col8, #T_3a504_row15_col3, #T_3a504_row15_col4, #T_3a504_row15_col5, #T_3a504_row15_col6, #T_3a504_row15_col7, #T_3a504_row15_col8, #T_3a504_row16_col3, #T_3a504_row16_col6, #T_3a504_row16_col7, #T_3a504_row16_col10, #T_3a504_row16_col11, #T_3a504_row16_col14, #T_3a504_row17_col3, #T_3a504_row17_col4, #T_3a504_row17_col5, #T_3a504_row17_col6, #T_3a504_row17_col7, #T_3a504_row17_col14, #T_3a504_row18_col4, #T_3a504_row18_col5, #T_3a504_row18_col7, #T_3a504_row18_col8, #T_3a504_row18_col9, #T_3a504_row18_col12, #T_3a504_row19_col3, #T_3a504_row19_col4, #T_3a504_row19_col5, #T_3a504_row19_col6, #T_3a504_row19_col7, #T_3a504_row19_col8, #T_3a504_row20_col3, #T_3a504_row20_col4, #T_3a504_row20_col5, #T_3a504_row20_col6, #T_3a504_row20_col7, #T_3a504_row20_col8, #T_3a504_row21_col3, #T_3a504_row21_col4, #T_3a504_row21_col5, #T_3a504_row21_col6, #T_3a504_row21_col7, #T_3a504_row21_col8, #T_3a504_row22_col3, #T_3a504_row22_col4, #T_3a504_row22_col5, #T_3a504_row22_col6, #T_3a504_row22_col7, #T_3a504_row22_col8, #T_3a504_row23_col3, #T_3a504_row23_col4, #T_3a504_row23_col5, #T_3a504_row23_col6, #T_3a504_row23_col7, #T_3a504_row23_col8, #T_3a504_row24_col3, #T_3a504_row24_col8, #T_3a504_row24_col10, #T_3a504_row24_col11, #T_3a504_row24_col12, #T_3a504_row24_col13, #T_3a504_row25_col3, #T_3a504_row25_col4, #T_3a504_row25_col5, #T_3a504_row25_col6, #T_3a504_row25_col7, #T_3a504_row25_col8, #T_3a504_row26_col3, #T_3a504_row26_col4, #T_3a504_row26_col5, #T_3a504_row26_col6, #T_3a504_row26_col7, #T_3a504_row26_col8, #T_3a504_row27_col3, #T_3a504_row27_col4, #T_3a504_row27_col5, #T_3a504_row27_col6, #T_3a504_row27_col7, #T_3a504_row27_col8, #T_3a504_row28_col3, #T_3a504_row28_col4, #T_3a504_row28_col5, #T_3a504_row28_col6, #T_3a504_row28_col7, #T_3a504_row28_col14, #T_3a504_row29_col3, #T_3a504_row29_col4, #T_3a504_row29_col5, #T_3a504_row29_col6, #T_3a504_row29_col7, #T_3a504_row29_col8, #T_3a504_row30_col5, #T_3a504_row30_col6, #T_3a504_row30_col9, #T_3a504_row30_col10, #T_3a504_row30_col13, #T_3a504_row30_col14, #T_3a504_row31_col3, #T_3a504_row31_col4, #T_3a504_row31_col5, #T_3a504_row31_col12, #T_3a504_row31_col13, #T_3a504_row31_col14 {
#   background-color: grey;
# }
# </style>
# <table id="T_3a504">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a504_level0_col0" class="col_heading level0 col0" >variable</th>
#       <th id="T_3a504_level0_col1" class="col_heading level0 col1" >condition</th>
#       <th id="T_3a504_level0_col2" class="col_heading level0 col2" >statistic</th>
#       <th id="T_3a504_level0_col3" class="col_heading level0 col3" colspan="6">Value Ours</th>
#       <th id="T_3a504_level0_col9" class="col_heading level0 col9" colspan="6">Value Benchmark</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_3a504_level1_col0" class="col_heading level1 col0" ></th>
#       <th id="T_3a504_level1_col1" class="col_heading level1 col1" ></th>
#       <th id="T_3a504_level1_col2" class="col_heading level1 col2" ></th>
#       <th id="T_3a504_level1_col3" class="col_heading level1 col3" >1 Days Horizon</th>
#       <th id="T_3a504_level1_col4" class="col_heading level1 col4" >2 Days Horizon</th>
#       <th id="T_3a504_level1_col5" class="col_heading level1 col5" >3 Days Horizon</th>
#       <th id="T_3a504_level1_col6" class="col_heading level1 col6" >4 Days Horizon</th>
#       <th id="T_3a504_level1_col7" class="col_heading level1 col7" >5 Days Horizon</th>
#       <th id="T_3a504_level1_col8" class="col_heading level1 col8" >6 Days Horizon</th>
#       <th id="T_3a504_level1_col9" class="col_heading level1 col9" >1 Days Horizon</th>
#       <th id="T_3a504_level1_col10" class="col_heading level1 col10" >2 Days Horizon</th>
#       <th id="T_3a504_level1_col11" class="col_heading level1 col11" >3 Days Horizon</th>
#       <th id="T_3a504_level1_col12" class="col_heading level1 col12" >4 Days Horizon</th>
#       <th id="T_3a504_level1_col13" class="col_heading level1 col13" >5 Days Horizon</th>
#       <th id="T_3a504_level1_col14" class="col_heading level1 col14" >6 Days Horizon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a504_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_3a504_row0_col0" class="data row0 col0" >F10</td>
#       <td id="T_3a504_row0_col1" class="data row0 col1" >low</td>
#       <td id="T_3a504_row0_col2" class="data row0 col2" >mean</td>
#       <td id="T_3a504_row0_col3" class="data row0 col3" >-0.071236</td>
#       <td id="T_3a504_row0_col4" class="data row0 col4" >0.259902</td>
#       <td id="T_3a504_row0_col5" class="data row0 col5" >0.093957</td>
#       <td id="T_3a504_row0_col6" class="data row0 col6" >0.332901</td>
#       <td id="T_3a504_row0_col7" class="data row0 col7" >0.209407</td>
#       <td id="T_3a504_row0_col8" class="data row0 col8" >-0.016804</td>
#       <td id="T_3a504_row0_col9" class="data row0 col9" >-0.268500</td>
#       <td id="T_3a504_row0_col10" class="data row0 col10" >-0.747200</td>
#       <td id="T_3a504_row0_col11" class="data row0 col11" >-0.667200</td>
#       <td id="T_3a504_row0_col12" class="data row0 col12" >-0.372100</td>
#       <td id="T_3a504_row0_col13" class="data row0 col13" >-0.067400</td>
#       <td id="T_3a504_row0_col14" class="data row0 col14" >0.242800</td>
#     </tr>
#     <tr>
#       <th id="T_3a504_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_3a504_row1_col0" class="data row1 col0" >F10</td>
#       <td id="T_3a504_row1_col1" class="data row1 col1" >low</td>
#       <td id="T_3a504_row1_col2" class="data row1 col2" >std</td>
#       <td id="T_3a504_row1_col3" class="data row1 col3" >1.696314</td>
#       <td id="T_3a504_row1_col4" class="data row1 col4" >2.168204</td>
#       <td id="T_3a504_row1_col5" class="data row1 col5" >2.773656</td>
#       <td id="T_3a504_row1_col6" class="data row1 col6" >3.255150</td>
#       <td id="T_3a504_row1_col7" class="data row1 col7" >3.777593</td>
#       <td id="T_3a504_row1_col8" class="data row1 col8" >4.021286</td>
#       <td id="T_3a504_row1_col9" class="data row1 col9" >3.698500</td>
#       <td id="T_3a504_row1_col10" class="data row1 col10" >4.703100</td>
#       <td id="T_3a504_row1

# %%
create_latex_comparison_tables(df_results_joined, data_columns_fcst, horizon)
# Out:
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable F10}
# \label{tab:comparison_F10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.07123593} ± \textbf{1.6963142} & -0.2685 ± 3.6985 \\
# low & 2 & \textbf{0.25990185} ± \textbf{2.1682036} & -0.7472 ± 4.7031 \\
# low & 3 & \textbf{0.09395675} ± \textbf{2.7736557} & -0.6672 ± 5.5001 \\
# low & 4 & \textbf{0.3329014} ± \textbf{3.25515} & -0.3721 ± 6.1683 \\
# low & 5 & 0.20940705 ± \textbf{3.7775934} & \textbf{-0.0674} ± 6.7677 \\
# low & 6 & \textbf{-0.016804025} ± \textbf{4.0212865} & 0.2428 ± 7.205 \\
# moderate & 1 & \textbf{-0.42657238} ± \textbf{3.7570035} & -0.8251 ± 12.0854 \\
# moderate & 2 & \textbf{0.02808998} ± \textbf{5.2447844} & -0.8095 ± 14.9853 \\
# moderate & 3 & \textbf{0.033293582} ± \textbf{6.4003477} & -0.9639 ± 17.8425 \\
# moderate & 4 & \textbf{-0.4732534} ± \textbf{7.5132084} & -1.145 ± 20.2973 \\
# moderate & 5 & \textbf{-0.20373805} ± \textbf{8.858162} & -1.1456 ± 21.9353 \\
# moderate & 6 & \textbf{-0.47523186} ± \textbf{10.058877} & -1.1679 ± 23.3389 \\
# elevated & 1 & \textbf{-3.264493} ± \textbf{5.0498133} & 5.727 ± 18.3328 \\
# elevated & 2 & \textbf{-3.672162} ± \textbf{7.633696} & 7.2425 ± 22.1021 \\
# elevated & 3 & \textbf{-3.8753085} ± \textbf{9.438831} & 9.0385 ± 25.2942 \\
# elevated & 4 & \textbf{-3.0996773} ± \textbf{11.299518} & 10.3829 ± 27.0774 \\
# elevated & 5 & \textbf{-2.6229885} ± \textbf{12.1878605} & 11.0017 ± 27.5279 \\
# elevated & 6 & \textbf{-1.2177008} ± \textbf{13.208594} & 10.9559 ± 26.9074 \\
# high & 1 & \textbf{-3.0222917} ± \textbf{4.4749036} & 15.7448 ± 20.2227 \\
# high & 2 & \textbf{-2.929564} ± \textbf{5.3609605} & 19.5749 ± 24.7236 \\
# high & 3 & \textbf{-3.6748664} ± \textbf{5.4178376} & 24.2444 ± 27.6092 \\
# high & 4 & \textbf{-5.8832045} ± \textbf{6.5994277} & 26.6674 ± 30.8869 \\
# high & 5 & \textbf{-4.4492455} ± \textbf{8.555874} & 26.023 ± 33.9069 \\
# high & 6 & \textbf{-1.5146518} ± \textbf{9.75179} & 23.9778 ± 35.9795 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable S10}
# \label{tab:comparison_S10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.18998607} ± \textbf{2.8608427} & 0.2206 ± 5.8378 \\
# low & 2 & -0.18565293 ± \textbf{5.2824306} & \textbf{-0.0343} ± 5.7474 \\
# low & 3 & -0.34982657 ± \textbf{4.428138} & \textbf{-0.1044} ± 5.8682 \\
# low & 4 & \textbf{-0.09164153} ± \textbf{5.3129582} & -0.0985 ± 6.0709 \\
# low & 5 & \textbf{0.021045098} ± \textbf{5.950978} & -0.066 ± 6.1153 \\
# low & 6 & -0.5120446 ± 7.5148087 & \textbf{-0.0501} ± \textbf{6.0475} \\
# moderate & 1 & -0.3707321 ± \textbf{3.676235} & \textbf{0.1111} ± 10.0715 \\
# moderate & 2 & \textbf{0.008241472} ± \textbf{5.0834775} & 0.219 ± 11.7059 \\
# moderate & 3 & \textbf{-0.12905328} ± \textbf{6.379656} & 0.2974 ± 13.5434 \\
# moderate & 4 & -0.5085844 ± \textbf{7.425281} & \textbf{0.3426} ± 14.9844 \\
# moderate & 5 & \textbf{-0.11319318} ± \textbf{8.693423} & 0.2977 ± 16.1132 \\
# moderate & 6 & \textbf{-0.14411698} ± \textbf{9.846501} & 0.1862 ± 17.1467 \\
# elevated & 1 & \textbf{-0.69868046} ± \textbf{4.095662} & -1.1311 ± 16.5592 \\
# elevated & 2 & \textbf{-0.7425448} ± \textbf{5.993514} & -1.7989 ± 19.205 \\
# elevated & 3 & \textbf{-0.571754} ± \textbf{7.430784} & -2.2361 ± 21.9271 \\
# elevated & 4 & \textbf{-0.8776449} ± \textbf{9.660759} & -2.691 ± 24.1118 \\
# elevated & 5 & \textbf{0.28385958} ± \textbf{10.082962} & -2.8148 ± 25.8017 \\
# elevated & 6 & \textbf{0.5445493} ± \textbf{10.984032} & -2.7593 ± 27.2658 \\
# high & 1 & \textbf{-1.2442415} ± \textbf{3.7109032} & 16.204 ± 35.3267 \\
# high & 2 & \textbf{-1.2014534} ± \textbf{5.973325} & 23.1628 ± 39.6577 \\
# high & 3 & \textbf{0.033225782} ± \textbf{9.711154} & 28.3943 ± 39.6471 \\
# high & 4 & \textbf{-0.30463734} ± \textbf{11.299147} & 31.4085 ± 38.7875 \\
# high & 5 & \textbf{1.6340942} ± \textbf{11.684377} & 31.6158 ± 38.5307 \\
# high & 6 & \textbf{3.1824083} ± \textbf{11.077234} & 30.1409 ± 38.6613 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable M10}
# \label{tab:comparison_M10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.18837278} ± \textbf{2.1672795} & -0.9582 ± 5.1317 \\
# low & 2 & \textbf{0.0840644} ± \textbf{2.843262} & -1.1063 ± 5.6375 \\
# low & 3 & \textbf{-0.13364205} ± \textbf{3.8202646} & -1.2667 ± 6.225 \\
# low & 4 & \textbf{0.18124907} ± \textbf{4.3579893} & -1.4203 ± 6.4693 \\
# low & 5 & \textbf{0.15628405} ± \textbf{4.9260464} & -1.5303 ± 6.8538 \\
# low & 6 & \textbf{-0.08533052} ± \textbf{5.080371} & -1.6171 ± 7.2024 \\
# moderate & 1 & \textbf{-0.510711} ± \textbf{3.697446} & -0.5138 ± 8.9027 \\
# moderate & 2 & \textbf{-0.17378692} ± \textbf{5.0739336} & -0.7424 ± 11.2745 \\
# moderate & 3 & \textbf{-0.1142399} ± \textbf{6.3083835} & -0.9976 ± 13.4329 \\
# moderate & 4 & \textbf{-0.7777911} ± \textbf{7.398797} & -1.1619 ± 15.1962 \\
# moderate & 5 & \textbf{-0.6043045} ± \textbf{8.662107} & -1.237 ± 16.4221 \\
# moderate & 6 & \textbf{-1.0131487} ± \textbf{9.759053} & -1.3348 ± 17.4041 \\
# elevated & 1 & \textbf{-2.38766} ± \textbf{4.9011755} & 3.7282 ± 10.4528 \\
# elevated & 2 & \textbf{-1.6024945} ± \textbf{7.369403} & 5.6301 ± 13.4784 \\
# elevated & 3 & \textbf{-0.79814166} ± \textbf{8.860009} & 7.3375 ± 16.1156 \\
# elevated & 4 & \textbf{1.0800468} ± \textbf{10.187113} & 8.5258 ± 17.9805 \\
# elevated & 5 & \textbf{2.3044689} ± \textbf{10.577886} & 9.0192 ± 18.9175 \\
# elevated & 6 & \textbf{4.7124357} ± \textbf{10.910546} & 8.9334 ± 19.077 \\
# high & 1 & \textbf{-1.0547165} ± \textbf{3.1227345} & 4.6517 ± 9.2079 \\
# high & 2 & \textbf{-0.45324197} ± \textbf{4.2047663} & 6.3966 ± 12.7892 \\
# high & 3 & \textbf{-0.2893209} ± \textbf{5.437541} & 8.8328 ± 16.4932 \\
# high & 4 & \textbf{-1.128407} ± \textbf{6.093189} & 10.95 ± 19.2241 \\
# high & 5 & \textbf{0.76272404} ± \textbf{7.243398} & 12.3435 ± 20.913 \\
# high & 6 & \textbf{3.1864738} ± \textbf{7.81416} & 12.9784 ± 21.582 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{Comparison of the results of the paper with the results of our model for the variable Y10}
# \label{tab:comparison_Y10}
# \begin{tabular}{|l||c||c||c||c||c||c|}
# \toprule
# condition & horizon & NN & benchmark \\
# \midrule
# low & 1 & \textbf{-0.07477644} ± \textbf{1.8740056} & -0.427 ± 4.5093 \\
# low & 2 & 0.30299455 ± \textbf{2.3819637} & \textbf{-0.2282} ± 4.9373 \\
# low & 3 & 0.16415125 ± \textbf{2.699992} & \textbf{-0.0684} ± 5.4416 \\
# low & 4 & 0.4427946 ± \textbf{3.1122367} & \textbf{0.0902} ± 5.9977 \\
# low & 5 & 0.42739743 ± \textbf{3.5454595} & \textbf{0.2697} ± 6.4255 \\
# low & 6 & \textbf{0.2143775} ± \textbf{3.3926392} & 0.465 ± 6.816 \\
# moderate & 1 & \textbf{-0.42167735} ± \textbf{3.6646695} & -0.8277 ± 8.5137 \\
# moderate & 2 & \textbf{-0.0145429475} ± \textbf{5.076239} & -1.3317 ± 10.1811 \\
# moderate & 3 & \textbf{-0.07096732} ± \textbf{6.242871} & -1.7651 ± 11.8475 \\
# moderate & 4 & \textbf{-0.5218334} ± \textbf{7.360046} & -2.1734 ± 13.017 \\
# moderate & 5 & \textbf{-0.18852574} ± \textbf{8.650176} & -2.5561 ± 13.8737 \\
# moderate & 6 & \textbf{-0.29233614} ± \textbf{9.801798} & -2.9688 ± 14.8937 \\
# elevated & 1 & \textbf{-1.1545717} ± \textbf{4.244579} & 2.1089 ± 7.7173 \\
# elevated & 2 & \textbf{-0.5746349} ± \textbf{6.450173} & 1.7243 ± 9.3066 \\
# elevated & 3 & \textbf{-0.573454} ± \textbf{8.027054} & 2.0679 ± 10.6086 \\
# elevated & 4 & \textbf{0.21845677} ± \textbf{9.517385} & 2.5656 ± 11.4955 \\
# elevated & 5 & \textbf{1.1551769} ± \textbf{9.851047} & 2.7714 ± 11.8996 \\
# elevated & 6 & 3.0912626 ± \textbf{10.670898} & \textbf{2.8423} ± 11.9965 \\
# high & 1 & -11.0539055 ± \textbf{6.584596} & \textbf{5.2729} ± 8.5806 \\
# high & 2 & -5.51569 ± \textbf{4.8973255} & \textbf{4.2075} ± 10.8097 \\
# high & 3 & \textbf{-1.6943169} ± \textbf{10.0225} & 4.5855 ± 11.5436 \\
# high & 4 & \textbf{1.363903} ± 11.905317 & 5.2131 ± \textbf{11.3048} \\
# high & 5 & 5.823387 ± 11.25566 & \textbf{5.6561} ± \textbf{11.019} \\
# high & 6 & 8.320732 ± 13.580637 & \textbf{6.014} ± \textbf{10.4416} \\
# \bottomrule
# \end{tabular}
# \end{table}
